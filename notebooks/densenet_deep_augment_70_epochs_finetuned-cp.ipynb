# %% [markdown]
# **X-Ray classification**
#
# **Deep augmentation**
#
# **70 epochs**
#
# **all**
#
# **more features to finetune**
#
# * **densenet**

# %% [markdown]
# # Libraries

# %%
import tensorflow as tf
import lib.data_loader as data_loader
import lib.plot_learning_curves as plot_learning_curves
import models.base_model as base_model
import models.densenet as densenet
import models.resnet as resnet
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import math
import matplotlib.image as mpimg
# from tqdm import tqdm
from PIL import Image
import tensorflow as tf
from tensorflow import keras
import random, os
import numpy as np
import pandas as pd
import json

# import cv2
import matplotlib.pyplot as plt
from matplotlib.pyplot import *

# %matplotlib inline
from mpl_toolkits.axes_grid1 import make_axes_locatable
from glob import glob
import gc
# from skimage.transform import resize
from tensorflow.keras import backend as K # Importing Keras backend (by default it is Tensorflow)
from tensorflow.keras.layers import Input, Conv2D, Dense, Dropout, Flatten, MaxPool2D # Layers to be used for building our model
from tensorflow.keras.models import Model # The class used to create a model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.random import set_seed

from sklearn.metrics import f1_score, recall_score, precision_score

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
! pip install -q -U keras-tuner
import keras_tuner as kt

from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.4.0
# Train model
# Tensorflow version 2.4.0
# Tensorflow version 2.4.0
# WARNING: You are using pip version 20.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Tensorflow version 2.4.0

# %% [markdown]
# # Data  munging

# %%
# mount data
data_path = 'data/MURA-v1.1/'
directory = 'data/'
train, test, bodyparts, bodyparts_train_validation_dict, train_generators, valid_generators, test_generators = data_loader.data_loader(data_augmentation='deep_augment')
# Out:
# Import train and test data
#
#
# Create dictionary for training and validation set per body part
#
# Doing a light data augmentation
#
# Create dictionary for training, validation and test set per body part
#
# Found 4423 validated image filenames.
# Found 508 validated image filenames.
# Found 465 validated image filenames.
# Found 1146 validated image filenames.
# Found 126 validated image filenames.
# Found 288 validated image filenames.
# Found 7564 validated image filenames.
# Found 815 validated image filenames.
# Found 563 validated image filenames.
# Found 1641 validated image filenames.
# Found 184 validated image filenames.
# Found 301 validated image filenames.
# Found 8768 validated image filenames.
# Found 984 validated image filenames.
# Found 659 validated image filenames.
# Found 4988 validated image filenames.
# Found 555 validated image filenames.
# Found 460 validated image filenames.
# Found 4564 validated image filenames.
# Found 542 validated image filenames.
# Found 461 validated image filenames.
# Data munging completed

# %% [markdown]
# # DenseNet

# %%
def clean_up(model):
    K.clear_session()
    del model
    gc.collect()

# %%
def build_model_on_densenet(hp, conv_dropout=True):

    #########################################
    ## set hyperparameters for fine tuning ##
    #########################################

    # tune the number of units
    hp_units = hp.Int('units', min_value=32, max_value=32*8, step=32)
    
    # tune the learning rate for the optimizer
    hp_learning_rate = hp.Choice('learning_rate', 
                                 values=[5*1e-4, 5*1e-1, 1e-3])
    optimizer = keras.optimizers.Adam(learning_rate=hp_learning_rate)

    # dropour rate
    dropout_rate = hp.Float('dropout', 0.1, 0.5, step=0.1, default=0.2)

    np.random.seed(1000) # Define the seed for numpy to have reproducible experiments.
    set_seed(150) # Define the seed for Tensorflow to have reproducible experiments.

    ###################
    ## define model ##
    ###################    
    # DenseNet model
    densenet_model = tf.keras.applications.DenseNet121(weights='imagenet',
                                                        input_shape = (320,320,3),
                                                        include_top = False)
    densenet_model.trainable = False
    # add new model on top
    inputs = tf.keras.Input(shape=(320,320,3))
    x = densenet_model(inputs, 
                        training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(dropout_rate)(x)    
    # Flatten the convolved images so as to input them to a Dense Layer
    x = Flatten(name='Flatten')(x)
    
    
    x = tf.keras.layers.Dense(units=hp_units,
                              activation='relu',
                              name='Dense-1')(x)
    x = tf.keras.layers.Dropout(dropout_rate)(x) 
    
    # Add a dense before output layer and drop out
    x = tf.keras.layers.Dense(units=hp_units,
                              activation='relu',
                              name='Dense-2')(x)
    x = tf.keras.layers.Dropout(dropout_rate)(x) 

    outputs = tf.keras.layers.Dense(1, 
                                      activation='sigmoid')(x)
    model = tf.keras.Model(inputs, 
                           outputs)
    model.summary()

    # train the top layer
    model.compile(optimizer = optimizer,
                    loss = 'binary_crossentropy',
                    metrics = ['binary_accuracy'])
    return model

# %%
# build tuner to fine-tune the hyper-parameters
# for the model
tuner = kt.Hyperband(
                    build_model_on_densenet,
                    objective='val_binary_accuracy',
                    max_epochs=30,
                    hyperband_iterations=2,
                    directory='data/fine_tuner_densenet_plus_dense_at_end',
                    project_name='densenet_70_epochs_plus_dense_at_end_monitor_val_accuracy'
)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 320, 320, 3)]     0
# _________________________________________________________________
# densenet121 (Functional)     (None, 10, 10, 1024)      7037504
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# Flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# Dense-1 (Dense)              (None, 32)                32800
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# Dense-2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 7,071,393
# Trainable params: 33,889
# Non-trainable params: 7,037,504
# _________________________________________________________________

# %%
validation_steps = math.ceil(valid_generators['XR_SHOULDER'].n/ (valid_generators['XR_SHOULDER'].batch_size))
print("Using validation_steps = %d" % validation_steps)
steps_per_epoch = math.ceil(train_generators['XR_SHOULDER'].n / (train_generators['XR_SHOULDER'].batch_size))
print("Using steps_per_epoch = %d" % steps_per_epoch)
# Out:
# Using validation_steps = 26
# Using steps_per_epoch = 237

# %%
# define the early stopping
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                              patience=8)
   
# perfrom search for best parameters
tuner.search(train_generators['XR_SHOULDER'], 
             validation_data=valid_generators['XR_SHOULDER'], 
             epochs=50, 
             callbacks=[stop_early],
             validation_steps=validation_steps,
             steps_per_epoch=steps_per_epoch)

# get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
# Out:
# Trial 53 Complete [00h 31m 54s]
# val_binary_accuracy: 0.6441717743873596
#
# Best val_binary_accuracy So Far: 0.7104294300079346
# Total elapsed time: 01h 29m 31s
#
# Search: Running Trial #54
#
# Value             |Best Value So Far |Hyperparameter
# 96                |256               |units
# 0.0005            |0.0005            |learning_rate
# 0.1               |0.1               |dropout
# 4                 |30                |tuner/epochs
# 0                 |10                |tuner/initial_epoch
# 2                 |3                 |tuner/bracket
# 0                 |3                 |tuner/round
#
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 320, 320, 3)]     0
# _________________________________________________________________
# densenet121 (Functional)     (None, 10, 10, 1024)      7037504
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# Flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# Dense-1 (Dense)              (None, 96)                98400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 96)                0
# _________________________________________________________________
# Dense-2 (Dense)              (None, 96)                9312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 96)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 97
# =================================================================
# Total params: 7,145,313
# Trainable params: 107,809
# Non-trainable params: 7,037,504
# _________________________________________________________________
# Epoch 1/4
# 237/237 [==============================] - 467s 2s/step - loss: 0.6791 - binary_accuracy: 0.5708 - val_loss: 0.6079 - val_binary_accuracy: 0.6613
# Epoch 2/4
# 237/237 [==============================] - 472s 2s/step - loss: 0.6344 - binary_accuracy: 0.6427 - val_loss: 0.6126 - val_binary_accuracy: 0.6699
# Epoch 3/4
# 237/237 [==============================] - 466s 2s/step - loss: 0.6088 - binary_accuracy: 0.6685 - val_loss: 0.6010 - val_binary_accuracy: 0.6810
# Epoch 4/4
#  13/237 [>.............................] - ETA: 6:11 - loss: 0.5932 - binary_accuracy: 0.6251

# %%
def build_model_on_densenet(hp, conv_dropout=True):

    #########################################
    ## set hyperparameters for fine tuning ##
    #########################################

    # tune the number of units
    hp_units = hp.Int('units', min_value=32, max_value=32*8, step=32)
    
    # tune the learning rate for the optimizer
    hp_learning_rate = hp.Choice('learning_rate', 
                                 values=[5*1e-4, 5*1e-1, 1e-3])
    optimizer = keras.optimizers.Adam(learning_rate=hp_learning_rate)

    # dropour rate
    dropout_rate = hp.Float('dropout', 0.1, 0.5, step=0.1, default=0.2)

    np.random.seed(1000) # Define the seed for numpy to have reproducible experiments.
    set_seed(150) # Define the seed for Tensorflow to have reproducible experiments.

    ###################
    ## define model ##
    ###################    
    # DenseNet model
    densenet_model = tf.keras.applications.DenseNet121(weights='imagenet',
                                                        input_shape = (320,320,3),
                                                        include_top = False)
    densenet_model.trainable = False
    # add new model on top
    inputs = tf.keras.Input(shape=(320,320,3))
    x = densenet_model(inputs, 
                        training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(dropout_rate)(x)    
    # Flatten the convolved images so as to input them to a Dense Layer
    x = Flatten(name='Flatten')(x)
    
    
    x = tf.keras.layers.Dense(units=hp_units,
                              activation='relu',
                              name='Dense-1')(x)
    x = tf.keras.layers.Dropout(dropout_rate)(x) 
    
    # Add a dense before output layer and drop out
    x = tf.keras.layers.Dense(units=hp_units,
                              activation='relu',
                              name='Dense-2')(x)
    x = tf.keras.layers.Dropout(dropout_rate)(x) 

    outputs = tf.keras.layers.Dense(1, 
                                      activation='sigmoid')(x)
    model = tf.keras.Model(inputs, 
                           outputs)
    model.summary()

    # train the top layer
    model.compile(optimizer = optimizer,
                    loss = 'binary_crossentropy',
                    metrics = ['binary_accuracy'])
    return model

# %%
   # tune the number of units
    hp_units = 256
    
    # tune the learning rate for the optimizer
    hp_learning_rate = 0.0005
    
    optimizer = keras.optimizers.Adam(learning_rate=hp_learning_rate)

    # dropour rate
    dropout_rate = 0.1

# %%
print('Learning rate: ', best_hps.get('learning_rate'), ', Dropout rate: ', best_hps.get('dropout'))

# %%
# build the model with the optimal hyperparameters 
# train it on the data for 50 epochs

model = build_model_on_densenet()
history = model.fit(train_generators['XR_SHOULDER'], 
             validation_data=valid_generators['XR_SHOULDER'], 
             epochs=50, 
             callbacks=[stop_early],
             validation_steps=validation_steps,
             steps_per_epoch=steps_per_epoch)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 320, 320, 3)]     0
# _________________________________________________________________
# densenet121 (Functional)     (None, 10, 10, 1024)      7037504
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# Flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# Dense-1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# Dense-2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 7,365,953
# Trainable params: 328,449
# Non-trainable params: 7,037,504
# _________________________________________________________________
# Epoch 1/50
# 237/237 [==============================] - 482s 2s/step - loss: 0.6929 - binary_accuracy: 0.5558 - val_loss: 0.6169 - val_binary_accuracy: 0.6515
# Epoch 2/50
# 237/237 [==============================] - 482s 2s/step - loss: 0.6255 - binary_accuracy: 0.6560 - val_loss: 0.6473 - val_binary_accuracy: 0.6282
# Epoch 3/50
# 237/237 [==============================] - 448s 2s/step - loss: 0.6065 - binary_accuracy: 0.6741 - val_loss: 0.5977 - val_binary_accuracy: 0.6785
# Epoch 4/50
# 237/237 [==============================] - 422s 2s/step - loss: 0.6033 - binary_accuracy: 0.6719 - val_loss: 0.5895 - val_binary_accuracy: 0.6883
# Epoch 5/50
# 237/237 [==============================] - 429s 2s/step - loss: 0.5960 - binary_accuracy: 0.6870 - val_loss: 0.5917 - val_binary_accuracy: 0.6933
# Epoch 6/50
# 237/237 [==============================] - 424s 2s/step - loss: 0.5901 - binary_accuracy: 0.6859 - val_loss: 0.5774 - val_binary_accuracy: 0.7006
# Epoch 7/50
# 237/237 [==============================] - 440s 2s/step - loss: 0.5851 - binary_accuracy: 0.6918 - val_loss: 0.5879 - val_binary_accuracy: 0.6994
# Epoch 8/50
# 237/237 [==============================] - 489s 2s/step - loss: 0.5795 - binary_accuracy: 0.6949 - val_loss: 0.5777 - val_binary_accuracy: 0.7067
# Epoch 9/50
# 237/237 [==============================] - 504s 2s/step - loss: 0.5691 - binary_accuracy: 0.7130 - val_loss: 0.5777 - val_binary_accuracy: 0.7006
# Epoch 10/50
# 237/237 [==============================] - 458s 2s/step - loss: 0.5722 - binary_accuracy: 0.7053 - val_loss: 0.5671 - val_binary_accuracy: 0.7129
# Epoch 11/50
# 237/237 [==============================] - 429s 2s/step - loss: 0.5723 - binary_accuracy: 0.7049 - val_loss: 0.5749 - val_binary_accuracy: 0.7031
# Epoch 12/50
# 237/237 [==============================] - 431s 2s/step - loss: 0.5788 - binary_accuracy: 0.6939 - val_loss: 0.5838 - val_binary_accuracy: 0.6994
# Epoch 13/50
# 237/237 [==============================] - 442s 2s/step - loss: 0.5610 - binary_accuracy: 0.7147 - val_loss: 0.6047 - val_binary_accuracy: 0.6736
# Epoch 14/50
# 237/237 [==============================] - 431s 2s/step - loss: 0.5648 - binary_accuracy: 0.7059 - val_loss: 0.5925 - val_binary_accuracy: 0.6896
# Epoch 15/50
# 237/237 [==============================] - 446s 2s/step - loss: 0.5587 - binary_accuracy: 0.7207 - val_loss: 0.5921 - val_binary_accuracy: 0.6883
# Epoch 16/50
# 237/237 [==============================] - 460s 2s/step - loss: 0.5625 - binary_accuracy: 0.7041 - val_loss: 0.5798 - val_binary_accuracy: 0.6957
# Epoch 17/50
# 237/237 [==============================] - 520s 2s/step - loss: 0.5509 - binary_accuracy: 0.7160 - val_loss: 0.5852 - val_binary_accuracy: 0.7055
# Epoch 18/50
# 237/237 [==============================] - 512s 2s/step - loss: 0.5619 - binary_accuracy: 0.7098 - val_loss: 0.5759 - val_binary_accuracy: 0.6933

# %%
# plot summary
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 320, 320, 3)]     0
# _________________________________________________________________
# densenet121 (Functional)     (None, 10, 10, 1024)      7037504
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# Flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# Dense-1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# Dense-2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 7,365,953
# Trainable params: 328,449
# Non-trainable params: 7,037,504
# _________________________________________________________________

# %%
# save model

model.save("data/models/finetuned_densenet_50_epochs_deep_augment_plus_dense_at_end.h5")
import json
with open("data/history/history_finetuned_densenet_50_epochs_deep_augment_plus_dense_at_end.json", "w") as file:
    json.dump(history.history, file)

# %%
plot_learning_curves.plot_history(history, 
                                 'XR_SHOULDER',
                                 'finetuned_densenet_plus_dense_at_end',
                                 50,
                                 data_augmentation='deep_augment')

# %%
def eval_func(y_true, y_prob):
    """
    A function calculating the different evaluation metrics on the test set.
    Converts prediction probabilities y_prob to predicted labels y_pred
    """
    y_pred = np.array([1 if prob >= 0.5 else 0 for prob in y_prob])
    y_true = np.array(y_true)

    print(f"Test accuracy: {round(accuracy_score(y_true, y_pred)*100, 2)} %")
    print(f"Test F1 score: {round(f1_score(y_true, y_pred)*100, 2)} %")
    print(f"Test Precision score: {round(precision_score(y_true, y_pred)*100, 2)} %")
    print(f"Test Recall score: {round(recall_score(y_true, y_pred)*100, 2)} %")

# %%
bodypart = 'XR_SHOULDER'

# %%
eval_func(test[test['bodypart'] == bodypart]['class'], 
                model.predict(test_generators[bodypart]))
test_loss, test_acc  = model.evaluate(test_generators[bodypart], verbose=0)
_, train_acc  = model.evaluate(train_generators[bodypart], verbose=0)
_, valid_acc  = model.evaluate(valid_generators[bodypart], verbose=0)
print("test_loss: ", round(100 * test_loss, 2))
print("test_acc: ", round(100 * test_acc, 2))
print("train_acc: ", round(100 * train_acc, 2))
print("valid_acc: ", round(100 * valid_acc, 2))
# Out:
# Test accuracy: 54.71 %
# Test F1 score: 42.95 %
# Test Precision score: 56.8 %
# Test Recall score: 34.53 %
# /usr/local/lib/python3.8/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.8/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# test_loss:  54.93
# test_acc:  71.05
# train_acc:  71.39
# valid_acc:  69.33
