# %% [markdown]
# **X-Ray classification**
#
# **Try all parts for 100 epochs - no data augmentation**
#
# Notes to fix:
#
# 1. Run evaluate to train and not test, Fixed!
# 2. Didn't delete model after fit, fit afresh new dataset, Fixed!
# 3. DenseNet and ResNet validation_steps and steps_per_epoch, Fix pending!
#
# Given a study containing X-Ray images, build a deep learning model that decides if the study is normal or abnormal.
#
# You must use at least **2 different architectures**,
# * one with your own CNN model (e.g., you can use a model similar to the CNN of the previous project) and
# * one with a popular CNN pre-trained CNN model (e.g., VGG-19, ResNet, etc.).
#
# Use the MURA dataset to train and evaluate your models. More information about the task and the dataset can be found [here](https://stanfordmlgroup.github.io/competitions/mura/). To download the dataset you must fill out a form, so complete this action as soon as possible.

# %% [markdown]
# # Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import math
import matplotlib.image as mpimg
# from tqdm import tqdm
from PIL import Image
import tensorflow as tf
from tensorflow import keras
import random, os
import numpy as np
import pandas as pd
# import cv2
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
# %matplotlib inline
from mpl_toolkits.axes_grid1 import make_axes_locatable
from glob import glob
import gc
# from skimage.transform import resize

from tensorflow.keras import backend as K # Importing Keras backend (by default it is Tensorflow)
from tensorflow.keras.layers import Input, Conv2D, Dense, Dropout, Flatten, MaxPool2D # Layers to be used for building our model
from tensorflow.keras.models import Model # The class used to create a model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.random import set_seed

from sklearn.metrics import f1_score, recall_score, precision_score

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
! pip install -q -U keras-tuner
import keras_tuner as kt

import json

from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

import lib.data_loader as data_loader
import lib.plot_learning_curves as plot_learning_curves
import models.base_model as base_model
import models.densenet as densenet
import models.resnet as resnet
# Out:
# WARNING: You are using pip version 20.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Tensorflow version 2.4.0
# Train model
# Tensorflow version 2.4.0
# Tensorflow version 2.4.0

# %%
# mount data from gdrive and change directory
data_path = 'data/MURA-v1.1/'
directory = 'data/'
! pwd
# Out:
# /tf

# %% [markdown]
# # Data  munging

# %%
train, test, bodyparts, bodyparts_train_validation_dict, train_generators, valid_generators, test_generators = data_loader.data_loader(data_augmentation='noaugment')
# Out:
# Import train and test data
#
#
# Create dictionary for training and validation set per body part
#
# No data augmentation
#
# Create dictionary for training, validation and test set per body part
#
# Found 5005 validated image filenames.
# Found 538 validated image filenames.
# Found 460 validated image filenames.
# Found 4590 validated image filenames.
# Found 516 validated image filenames.
# Found 461 validated image filenames.
# Found 8800 validated image filenames.
# Found 952 validated image filenames.
# Found 659 validated image filenames.
# Found 7528 validated image filenames.
# Found 851 validated image filenames.
# Found 563 validated image filenames.
# Found 4427 validated image filenames.
# Found 504 validated image filenames.
# Found 465 validated image filenames.
# Found 1638 validated image filenames.
# Found 187 validated image filenames.
# Found 301 validated image filenames.
# Found 1142 validated image filenames.
# Found 130 validated image filenames.
# Found 288 validated image filenames.
# Data munging completed

# %% [markdown]
# # CNN  with no augmentation

# %% [markdown]
# ## Build

# %%
def build_model(input_shape,
                conv_layers,
                conv_activation,
                conv_dropout,
                units,
                output_activation,
                optimizer,
                loss,
                metrics,
                verbose=1):
    
    np.random.seed(1234) # Define the seed for numpy to have reproducible experiments.
    set_seed(9876) # Define the seed for Tensorflow to have reproducible experiments.
    
    # Define the input layer.
    input = Input(
        shape=input_shape,
        name='Input'
    )

    x = input
    # Define the convolutional layers.
    for i in range(conv_layers):
        x = Conv2D(
            filters=8*(2**(i+1)),
            kernel_size=(3, 3),
            strides=(1, 1),
            padding='same',
            dilation_rate=(1, 1),
            activation=conv_activation,
            name='Conv2D-{0:d}'.format(i + 1)
        )(x)
        x = MaxPool2D(
            pool_size=(2, 2),
            strides=(2, 2),
            padding='same',
            name='MaxPool2D-{0:d}'.format(i + 1)
        )(x)
        if conv_dropout:
            x = Dropout(
                rate=0.2,
                name='Dropout-{0:d}'.format(i + 1)
            )(x)
    # Flatten the convolved images so as to input them to a Dense Layer
    x = Flatten(name='Flatten')(x)
    
    # Add a dense before output layer and drop out
    x = tf.keras.layers.Dense(units=100,
                              activation='relu',
                              name='Dense-1')(x)

    x = tf.keras.layers.Dropout(rate= 0.2, 
                                name='Dropout-{0:d}'.format(conv_layers + 1))(x)
    # Define the output layer.
    output = Dense(
        units=units,
        activation=output_activation,
        name='Output'
    )(x)

    # Define the model and train it.
    model = Model(inputs=input, 
                  outputs=output)
    model.compile(optimizer=optimizer, 
                  loss=loss, 
                  metrics=metrics)
    
    # print summary and architecture
    model.summary()

    return model

# %%
def build_cnn_model():
    model = build_model(input_shape = (320,320,3),
                        conv_layers = 4,
                        conv_activation = 'relu',
                        conv_dropout = 0.2,
                        units = 1,
                        output_activation = 'sigmoid',
                        optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3),
                        loss = 'binary_crossentropy',
                        metrics = ['binary_accuracy'])
    return model

# %%
def clean_up(model):
    K.clear_session()
    del model
    gc.collect()

# %% [markdown]
# ## Train

# %%
callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                             patience=8,
                                             verbose=1)    
def train_model(model, bodypart):
    
    validation_steps = math.ceil(valid_generators[bodypart].n/ valid_generators[bodypart].batch_size)
    print("Using validation_steps = %d" % validation_steps)
    steps_per_epoch = math.ceil(train_generators[bodypart].n / (train_generators[bodypart].batch_size))
    print("Using steps_per_epoch = %d" % steps_per_epoch)

    history = model.fit(train_generators[bodypart],
                        validation_data = valid_generators[bodypart],
                        validation_steps = validation_steps,
                        steps_per_epoch = steps_per_epoch,
                        epochs=100,
                        verbose=1,
                        callbacks=[callbacks]
    )
    return history

# %% [markdown]
# ## Evaluate

# %%
def eval_func(y_true, y_prob):
    """
    A function calculating the different evaluation metrics on the test set.
    Converts prediction probabilities y_prob to predicted labels y_pred
    """
    y_pred = np.array([1 if prob >= 0.5 else 0 for prob in y_prob])
    y_true = np.array(y_true)

    print(f"Test accuracy: {round(accuracy_score(y_true, y_pred)*100, 2)} %")
    print(f"Test F1 score: {round(f1_score(y_true, y_pred)*100, 2)} %")
    print(f"Test Precision score: {round(precision_score(y_true, y_pred)*100, 2)} %")
    print(f"Test Recall score: {round(recall_score(y_true, y_pred)*100, 2)} %")

# %%
histories_cnn = {}
for bodypart in set(train.bodypart):
    print(bodypart)
    print("\nBuild model\n")
    model = build_cnn_model()
    print('\nTrain model\n')
    print(bodypart)
    histories_cnn[bodypart] = train_model(model, 
                              bodypart)
    print('\nSave training history\n')
    with open("data/history/history_model_cnn_100epochs_noaugment_"+bodypart+".json", "w") as file:
        json.dump(histories_cnn[bodypart].history, file)
    print('\nSave model\n')
    model.save("data/models/model_cnn_100epochs_noaugment_"+bodypart)
    model.save("data/models/model_cnn_100epochs_noaugment_"+bodypart+".h5")
    print('\nEvaluate model\n')
    eval_func(test[test['bodypart'] == bodypart]['class'], 
                    model.predict(test_generators[bodypart]))
    model.evaluate(test_generators[bodypart], verbose=1)
    model.evaluate(train_generators[bodypart], verbose=1)
    model.evaluate(valid_generators[bodypart], verbose=1)
    print("Delete model")
    clean_up(model)
# Out:
# XR_FOREARM
#
# Build model
#
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 320, 320, 3)]     0
# _________________________________________________________________
# Conv2D-1 (Conv2D)            (None, 320, 320, 16)      448
# _________________________________________________________________
# MaxPool2D-1 (MaxPooling2D)   (None, 160, 160, 16)      0
# _________________________________________________________________
# Dropout-1 (Dropout)          (None, 160, 160, 16)      0
# _________________________________________________________________
# Conv2D-2 (Conv2D)            (None, 160, 160, 32)      4640
# _________________________________________________________________
# MaxPool2D-2 (MaxPooling2D)   (None, 80, 80, 32)        0
# _________________________________________________________________
# Dropout-2 (Dropout)          (None, 80, 80, 32)        0
# _________________________________________________________________
# Conv2D-3 (Conv2D)            (None, 80, 80, 64)        18496
# _________________________________________________________________
# MaxPool2D-3 (MaxPooling2D)   (None, 40, 40, 64)        0
# _________________________________________________________________
# Dropout-3 (Dropout)          (None, 40, 40, 64)        0
# _________________________________________________________________
# Conv2D-4 (Conv2D)            (None, 40, 40, 128)       73856
# _________________________________________________________________
# MaxPool2D-4 (MaxPooling2D)   (None, 20, 20, 128)       0
# _________________________________________________________________
# Dropout-4 (Dropout)          (None, 20, 20, 128)       0
# _________________________________________________________________
# Flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# Dense-1 (Dense)              (None, 100)               5120100
# _________________________________________________________________
# Dropout-5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 101
# =================================================================
# Total params: 5,217,641
# Trainable params: 5,217,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Train model
#
# XR_FOREARM
# Using validation_steps = 6
# Using steps_per_epoch = 52
# Epoch 1/100
# 52/52 [==============================] - 105s 2s/step - loss: 0.7788 - binary_accuracy: 0.6206 - val_loss: 0.6674 - val_binary_accuracy: 0.6474
# Epoch 2/100
# 52/52 [==============================] - 105s 2s/step - loss: 0.6644 - binary_accuracy: 0.6211 - val_loss: 0.6482 - val_binary_accuracy: 0.6474
# Epoch 3/100
# 52/52 [==============================] - 106s 2s/step - loss: 0.6573 - binary_accuracy: 0.6367 - val_loss: 0.6490 - val_binary_accuracy: 0.6474
# Epoch 4/100
# 52/52 [==============================] - 109s 2s/step - loss: 0.6542 - binary_accuracy: 0.6262 - val_loss: 0.6422 - val_binary_accuracy: 0.6474
# Epoch 5/100
# 52/52 [==============================] - 115s 2s/step - loss: 0.6363 - binary_accuracy: 0.6449 - val_loss: 0.6408 - val_binary_accuracy: 0.6590
# Epoch 6/100
# 52/52 [==============================] - 120s 2s/step - loss: 0.5968 - binary_accuracy: 0.6730 - val_loss: 0.6423 - val_binary_accuracy: 0.6705
# Epoch 7/100
# 52/52 [==============================] - 123s 2s/step - loss: 0.5520 - binary_accuracy: 0.7221 - val_loss: 0.6470 - val_binary_accuracy: 0.6012
# Epoch 8/100
# 52/52 [==============================] - 124s 2s/step - loss: 0.4819 - binary_accuracy: 0.7594 - val_loss: 0.7450 - val_binary_accuracy: 0.6127
# Epoch 9/100
# 52/52 [==============================] - 121s 2s/step - loss: 0.4019 - binary_accuracy: 0.7916 - val_loss: 0.9213 - val_binary_accuracy: 0.6647
# Epoch 10/100
# 52/52 [==============================] - 122s 2s/step - loss: 0.3257 - binary_accuracy: 0.8567 - val_loss: 0.9667 - val_binary_accuracy: 0.6358
# Epoch 11/100
# 52/52 [==============================] - 129s 2s/step - loss: 0.2222 - binary_accuracy: 0.9105 - val_loss: 1.2724 - val_binary_accuracy: 0.6590
# Epoch 12/100
# 52/52 [==============================] - 125s 2s/step - loss: 0.1509 - binary_accuracy: 0.9498 - val_loss: 1.7195 - val_binary_accuracy: 0.6185
# Epoch 13/100
# 52/52 [==============================] - 126s 2s/step - loss: 0.1213 - binary_accuracy: 0.9551 - val_loss: 2.1229 - val_binary_accuracy: 0.6416
# Epoch 00013: early stopping
#
# Save training history
#
#
# Save model
#
# INFO:tensorflow:Assets written to: data/models/model_cnn_100epochs_noaugment_XR_FOREARM/assets
#
# Evaluate model
#
# Test accuracy: 47.51 %
# Test F1 score: 40.15 %
# Test Precision score: 46.9 %
# Test Recall score: 35.1 %
# 10/10 [==============================] - 4s 412ms/step - loss: 2.5668 - binary_accuracy: 0.5615
# 52/52 [==============================] - 28s 532ms/step - loss: 0.0534 - binary_accuracy: 0.9849
# 6/6 [==============================] - 3s 394ms/step - loss: 2.1229 - binary_accuracy: 0.6416
# Delete model
# XR_HAND
#
# Build model
#
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 320, 320, 3)]     0
# _________________________________________________________________
# Conv2D-1 (Conv2D)            (None, 320, 320, 16)      448
# _________________________________________________________________
# MaxPool2D-1 (MaxPooling2D)   (None, 160, 160, 16)      0
# _________________________________________________________________
# Dropout-1 (Dropout)          (None, 160, 160, 16)      0
# _________________________________________________________________
# Conv2D-2 (Conv2D)            (None, 160, 160, 32)      4640
# _________________________________________________________________
# MaxPool2D-2 (MaxPooling2D)   (None, 80, 80, 32)        0
# _________________________________________________________________
# Dropout-2 (Dropout)          (None, 80, 80, 32)        0
# _________________________________________________________________
# Conv2D-3 (Conv2D)            (None, 80, 80, 64)        18496
# _________________________________________________________________
# MaxPool2D-3 (MaxPooling2D)   (None, 40, 40, 64)        0
# _________________________________________________________________
# Dropout-3 (Dropout)          (None, 40, 40, 64)        0
# _________________________________________________________________
# Conv2D-4 (Conv2D)            (None, 40, 40, 128)       73856
# _________________________________________________________________
# MaxPool2D-4 (MaxPooling2D)   (None, 20, 20, 128)       0
# _________________________________________________________________
# Dropout-4 (Dropout)          (None, 20, 20, 128)       0
# _________________________________________________________________
# Flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# Dense-1 (Dense)              (None, 100)               5120100
# _________________________________________________________________
# Dropout-5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 101
# =================================================================
# Total params: 5,217,641
# Trainable params: 5,217,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Train model
#
# XR_HAND
# Using validation_steps = 18
# Using steps_per_epoch = 157
# Epoch 1/100
# 157/157 [==============================] - 409s 3s/step - loss: 0.6590 - binary_accuracy: 0.7178 - val_loss: 0.5343 - val_binary_accuracy: 0.7821
# Epoch 2/100
# 157/157 [==============================] - 400s 3s/step - loss: 0.5678 - binary_accuracy: 0.7360 - val_loss: 0.5299 - val_binary_accuracy: 0.7821
# Epoch 3/100
# 157/157 [==============================] - 416s 3s/step - loss: 0.5606 - binary_accuracy: 0.7261 - val_loss: 0.5312 - val_binary_accuracy: 0.7802
# Epoch 4/100
# 157/157 [==============================] - 421s 3s/step - loss: 0.5519 - binary_accuracy: 0.7175 - val_loss: 0.5263 - val_binary_accuracy: 0.7821
# Epoch 5/100
# 157/157 [==============================] - 415s 3s/step - loss: 0.5190 - binary_accuracy: 0.7399 - val_loss: 0.5274 - val_binary_accuracy: 0.7637
# Epoch 6/100
# 157/157 [==============================] - 442s 3s/step - loss: 0.4932 - binary_accuracy: 0.7569 - val_loss: 0.5363 - val_binary_accuracy: 0.7546
# Epoch 7/100
# 157/157 [==============================] - 426s 3s/step - loss: 0.4614 - binary_accuracy: 0.7676 - val_loss: 0.5435 - val_binary_accuracy: 0.7564
# Epoch 8/100
# 157/157 [==============================] - 325s 2s/step - loss: 0.4216 - binary_accuracy: 0.8063 - val_loss: 0.5888 - val_binary_accuracy: 0.7070
# Epoch 9/100
# 157/157 [==============================] - 300s 2s/step - loss: 0.3706 - binary_accuracy: 0.8304 - val_loss: 0.6347 - val_binary_accuracy: 0.7015
# Epoch 10/100
# 157/157 [==============================] - 304s 2s/step - loss: 0.3124 - binary_accuracy: 0.8521 - val_loss: 0.6483 - val_binary_accuracy: 0.7253
# Epoch 11/100
# 157/157 [==============================] - 309s 2s/step - loss: 0.2431 - binary_accuracy: 0.8997 - val_loss: 0.7468 - val_binary_accuracy: 0.7308
# Epoch 12/100
# 157/157 [==============================] - 313s 2s/step - loss: 0.2225 - binary_accuracy: 0.9060 - val_loss: 0.8301 - val_binary_accuracy: 0.6777
# Epoch 00012: early stopping
#
# Save training history
#
#
# Save model
#
# INFO:tensorflow:Assets written to: data/models/model_cnn_100epochs_noaugment_XR_HAND/assets
#
# Evaluate model
#
# Test accuracy: 51.74 %
# Test F1 score: 25.5 %
# Test Precision score: 34.86 %
# Test Recall score: 20.11 %
# 15/15 [==============================] - 6s 365ms/step - loss: 1.4626 - binary_accuracy: 0.6043
# 157/157 [==============================] - 60s 378ms/step - loss: 0.1616 - binary_accuracy: 0.9528
# 18/18 [==============================] - 7s 384ms/step - loss: 0.8301 - binary_accuracy: 0.6777
# Delete model
# XR_HUMERUS
#
# Build model
#
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 320, 320, 3)]     0
# _________________________________________________________________
# Conv2D-1 (Conv2D)            (None, 320, 320, 16)      448
# _________________________________________________________________
# MaxPool2D-1 (MaxPooling2D)   (None, 160, 160, 16)      0
# _________________________________________________________________
# Dropout-1 (Dropout)          (None, 160, 160, 16)      0
# _________________________________________________________________
# Conv2D-2 (Conv2D)            (None, 160, 160, 32)      4640
# _________________________________________________________________
# MaxPool2D-2 (MaxPooling2D)   (None, 80, 80, 32)        0
# _________________________________________________________________
# Dropout-2 (Dropout)          (None, 80, 80, 32)        0
# _________________________________________________________________
# Conv2D-3 (Conv2D)            (None, 80, 80, 64)        18496
# _________________________________________________________________
# MaxPool2D-3 (MaxPooling2D)   (None, 40, 40, 64)        0
# _________________________________________________________________
# Dropout-3 (Dropout)          (None, 40, 40, 64)        0
# _________________________________________________________________
# Conv2D-4 (Conv2D)            (None, 40, 40, 128)       73856
# _________________________________________________________________
# MaxPool2D-4 (MaxPooling2D)   (None, 20, 20, 128)       0
# _________________________________________________________________
# Dropout-4 (Dropout)          (None, 20, 20, 128)       0
# _________________________________________________________________
# Flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# Dense-1 (Dense)              (None, 100)               5120100
# _________________________________________________________________
# Dropout-5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 101
# =================================================================
# Total params: 5,217,641
# Trainable params: 5,217,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Train model
#
# XR_HUMERUS
# Using validation_steps = 4
# Using steps_per_epoch = 36
# Epoch 1/100
# 36/36 [==============================] - 75s 2s/step - loss: 0.8923 - binary_accuracy: 0.5459 - val_loss: 0.6932 - val_binary_accuracy: 0.4797
# Epoch 2/100
# 36/36 [==============================] - 71s 2s/step - loss: 0.6893 - binary_accuracy: 0.5479 - val_loss: 0.6893 - val_binary_accuracy: 0.5447
# Epoch 3/100
# 36/36 [==============================] - 72s 2s/step - loss: 0.6864 - binary_accuracy: 0.5295 - val_loss: 0.6664 - val_binary_accuracy: 0.6992
# Epoch 4/100
# 36/36 [==============================] - 72s 2s/step - loss: 0.6928 - binary_accuracy: 0.5484 - val_loss: 0.6395 - val_binary_accuracy: 0.6423
# Epoch 5/100
# 36/36 [==============================] - 72s 2s/step - loss: 0.6625 - binary_accuracy: 0.5999 - val_loss: 0.6565 - val_binary_accuracy: 0.6748
# Epoch 6/100
# 36/36 [==============================] - 72s 2s/step - loss: 0.6235 - binary_accuracy: 0.6740 - val_loss: 0.6860 - val_binary_accuracy: 0.6179
# Epoch 7/100
# 36/36 [==============================] - 73s 2s/step - loss: 0.5916 - binary_accuracy: 0.6865 - val_loss: 0.6943 - val_binary_accuracy: 0.5854
# Epoch 8/100
# 36/36 [==============================] - 74s 2s/step - loss: 0.4859 - binary_accuracy: 0.7452 - val_loss: 0.7572 - val_binary_accuracy: 0.6016
# Epoch 9/100
# 36/36 [==============================] - 74s 2s/step - loss: 0.3952 - binary_accuracy: 0.8249 - val_loss: 0.8224 - val_binary_accuracy: 0.5447
# Epoch 10/100
# 36/36 [==============================] - 74s 2s/step - loss: 0.3788 - binary_accuracy: 0.8431 - val_loss: 1.1064 - val_binary_accuracy: 0.6179
# Epoch 11/100
# 36/36 [==============================] - 72s 2s/step - loss: 0.2186 - binary_accuracy: 0.9127 - val_loss: 1.4439 - val_binary_accuracy: 0.5610
# Epoch 12/100
# 36/36 [==============================] - 73s 2s/step - loss: 0.1672 - binary_accuracy: 0.9379 - val_loss: 1.6337 - val_binary_accuracy: 0.6260
# Epoch 00012: early stopping
#
# Save training history
#
#
# Save model
#
# INFO:tensorflow:Assets written to: data/models/model_cnn_100epochs_noaugment_XR_HUMERUS/assets
#
# Evaluate model
#
# Test accuracy: 53.82 %
# Test F1 score: 51.28 %
# Test Precision score: 52.63 %
# Test Recall score: 50.0 %
# 9/9 [==============================] - 4s 435ms/step - loss: 1.7213 - binary_accuracy: 0.5521
# 36/36 [==============================] - 15s 405ms/step - loss: 0.0984 - binary_accuracy: 0.9748
# 4/4 [==============================] - 2s 361ms/step - loss: 1.6337 - binary_accuracy: 0.6260
# Delete model
# XR_SHOULDER
#
# Build model
#
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 320, 320, 3)]     0
# _________________________________________________________________
# Conv2D-1 (Conv2D)            (None, 320, 320, 16)      448
# _________________________________________________________________
# MaxPool2D-1 (MaxPooling2D)   (None, 160, 160, 16)      0
# _________________________________________________________________
# Dropout-1 (Dropout)          (None, 160, 160, 16)      0
# _________________________________________________________________
# Conv2D-2 (Conv2D)            (None, 160, 160, 32)      4640
# _________________________________________________________________
# MaxPool2D-2 (MaxPooling2D)   (None, 80, 80, 32)        0
# _________________________________________________________________
# Dropout-2 (Dropout)          (None, 80, 80, 32)        0
# _________________________________________________________________
# Conv2D-3 (Conv2D)            (None, 80, 80, 64)        18496
# _________________________________________________________________
# MaxPool2D-3 (MaxPooling2D)   (None, 40, 40, 64)        0
# _________________________________________________________________
# Dropout-3 (Dropout)          (None, 40, 40, 64)        0
# _________________________________________________________________
# Conv2D-4 (Conv2D)            (None, 40, 40, 128)       73856
# _________________________________________________________________
# MaxPool2D-4 (MaxPooling2D)   (None, 20, 20, 128)       0
# _________________________________________________________________
# Dropout-4 (Dropout)          (None, 20, 20, 128)       0
# _________________________________________________________________
# Flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# Dense-1 (Dense)              (None, 100)               5120100
# _________________________________________________________________
# Dropout-5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 101
# =================================================================
# Total params: 5,217,641
# Trainable params: 5,217,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Train model
#
# XR_SHOULDER
# Using validation_steps = 27
# Using steps_per_epoch = 236
# Epoch 1/100
# 236/236 [==============================] - 475s 2s/step - loss: 0.7429 - binary_accuracy: 0.5160 - val_loss: 0.6818 - val_binary_accuracy: 0.5945
# Epoch 2/100
# 236/236 [==============================] - 504s 2s/step - loss: 0.6776 - binary_accuracy: 0.5812 - val_loss: 0.6721 - val_binary_accuracy: 0.5945
# Epoch 3/100
# 236/236 [==============================] - 504s 2s/step - loss: 0.6446 - binary_accuracy: 0.6229 - val_loss: 0.6522 - val_binary_accuracy: 0.6376
# Epoch 4/100
# 236/236 [==============================] - 508s 2s/step - loss: 0.6144 - binary_accuracy: 0.6453 - val_loss: 0.6641 - val_binary_accuracy: 0.6184
# Epoch 5/100
# 236/236 [==============================] - 524s 2s/step - loss: 0.5672 - binary_accuracy: 0.7128 - val_loss: 0.6348 - val_binary_accuracy: 0.6340
# Epoch 6/100
# 236/236 [==============================] - 520s 2s/step - loss: 0.5368 - binary_accuracy: 0.7276 - val_loss: 0.6307 - val_binary_accuracy: 0.6543
# Epoch 7/100
# 236/236 [==============================] - 524s 2s/step - loss: 0.5047 - binary_accuracy: 0.7404 - val_loss: 0.6811 - val_binary_accuracy: 0.6543
# Epoch 8/100
# 236/236 [==============================] - 538s 2s/step - loss: 0.4598 - binary_accuracy: 0.7748 - val_loss: 0.7124 - val_binary_accuracy: 0.6376
# Epoch 9/100
# 236/236 [==============================] - 493s 2s/step - loss: 0.3931 - binary_accuracy: 0.8186 - val_loss: 0.7509 - val_binary_accuracy: 0.6567
# Epoch 10/100
# 236/236 [==============================] - 519s 2s/step - loss: 0.3496 - binary_accuracy: 0.8375 - val_loss: 0.8283 - val_binary_accuracy: 0.6316
# Epoch 11/100
# 236/236 [==============================] - 505s 2s/step - loss: 0.3042 - binary_accuracy: 0.8675 - val_loss: 0.8484 - val_binary_accuracy: 0.6400
# Epoch 12/100
# 236/236 [==============================] - 511s 2s/step - loss: 0.2487 - binary_accuracy: 0.8962 - val_loss: 0.9230 - val_binary_accuracy: 0.6519
# Epoch 13/100
# 236/236 [==============================] - 519s 2s/step - loss: 0.2258 - binary_accuracy: 0.9064 - val_loss: 1.0923 - val_binary_accuracy: 0.6471
# Epoch 14/100
# 236/236 [==============================] - 513s 2s/step - loss: 0.1822 - binary_accuracy: 0.9279 - val_loss: 1.1118 - val_binary_accuracy: 0.6364
# Epoch 00014: early stopping
#
# Save training history
#
#
# Save model
#
# INFO:tensorflow:Assets written to: data/models/model_cnn_100epochs_noaugment_XR_SHOULDER/assets
#
# Evaluate model
#
# Test accuracy: 52.75 %
# Test F1 score: 53.66 %
# Test Precision score: 52.03 %
# Test Recall score: 55.4 %
# 18/18 [==============================] - 8s 421ms/step - loss: 1.0890 - binary_accuracy: 0.6661
# 236/236 [==============================] - 99s 417ms/step - loss: 0.1259 - binary_accuracy: 0.9623
# 27/27 [==============================] - 11s 387ms/step - loss: 1.1118 - binary_accuracy: 0.6364
# Delete model
# XR_WRIST
#
# Build model
#
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 320, 320, 3)]     0
# _________________________________________________________________
# Conv2D-1 (Conv2D)            (None, 320, 320, 16)      448
# _________________________________________________________________
# MaxPool2D-1 (MaxPooling2D)   (None, 160, 160, 16)      0
# _________________________________________________________________
# Dropout-1 (Dropout)          (None, 160, 160, 16)      0
# _________________________________________________________________
# Conv2D-2 (Conv2D)            (None, 160, 160, 32)      4640
# _________________________________________________________________
# MaxPool2D-2 (MaxPooling2D)   (None, 80, 80, 32)        0
# _________________________________________________________________
# Dropout-2 (Dropout)          (None, 80, 80, 32)        0
# _________________________________________________________________
# Conv2D-3 (Conv2D)            (None, 80, 80, 64)        18496
# _________________________________________________________________
# MaxPool2D-3 (MaxPooling2D)   (None, 40, 40, 64)        0
# _________________________________________________________________
# Dropout-3 (Dropout)          (None, 40, 40, 64)        0
# _________________________________________________________________
# Conv2D-4 (Conv2D)            (None, 40, 40, 128)       73856
# _________________________________________________________________
# MaxPool2D-4 (MaxPooling2D)   (None, 20, 20, 128)       0
# _________________________________________________________________
# Dropout-4 (Dropout)          (None, 20, 20, 128)       0
# _________________________________________________________________
# Flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# Dense-1 (Dense)              (None, 100)               5120100
# _________________________________________________________________
# Dropout-5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 101
# =================================================================
# Total params: 5,217,641
# Trainable params: 5,217,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Train model
#
# XR_WRIST
# Using validation_steps = 31
# Using steps_per_epoch = 275
# Epoch 1/100
# 275/275 [==============================] - 599s 2s/step - loss: 0.6946 - binary_accuracy: 0.5910 - val_loss: 0.6720 - val_binary_accuracy: 0.5786
# Epoch 2/100
# 275/275 [==============================] - 610s 2s/step - loss: 0.6384 - binary_accuracy: 0.6389 - val_loss: 0.6424 - val_binary_accuracy: 0.6153
# Epoch 3/100
# 275/275 [==============================] - 610s 2s/step - loss: 0.6023 - binary_accuracy: 0.6751 - val_loss: 0.6238 - val_binary_accuracy: 0.6520
# Epoch 4/100
# 275/275 [==============================] - 597s 2s/step - loss: 0.5751 - binary_accuracy: 0.6924 - val_loss: 0.6157 - val_binary_accuracy: 0.6704
# Epoch 5/100
# 275/275 [==============================] - 582s 2s/step - loss: 0.5339 - binary_accuracy: 0.7270 - val_loss: 0.6327 - val_binary_accuracy: 0.6265
# Epoch 6/100
# 275/275 [==============================] - 592s 2s/step - loss: 0.4890 - binary_accuracy: 0.7506 - val_loss: 0.6464 - val_binary_accuracy: 0.6735
# Epoch 7/100
# 275/275 [==============================] - 580s 2s/step - loss: 0.4336 - binary_accuracy: 0.7868 - val_loss: 0.6915 - val_binary_accuracy: 0.6520
# Epoch 8/100
# 275/275 [==============================] - 608s 2s/step - loss: 0.3539 - binary_accuracy: 0.8304 - val_loss: 0.7181 - val_binary_accuracy: 0.6582
# Epoch 9/100
# 275/275 [==============================] - 598s 2s/step - loss: 0.3038 - binary_accuracy: 0.8680 - val_loss: 0.8051 - val_binary_accuracy: 0.6541
# Epoch 10/100
# 275/275 [==============================] - 597s 2s/step - loss: 0.2363 - binary_accuracy: 0.8948 - val_loss: 0.9910 - val_binary_accuracy: 0.6786
# Epoch 11/100
# 275/275 [==============================] - 577s 2s/step - loss: 0.1941 - binary_accuracy: 0.9203 - val_loss: 1.1367 - val_binary_accuracy: 0.6857
# Epoch 12/100
# 275/275 [==============================] - 576s 2s/step - loss: 0.1652 - binary_accuracy: 0.9309 - val_loss: 1.2585 - val_binary_accuracy: 0.6592
# Epoch 00012: early stopping
#
# Save training history
#
#
# Save model
#
# INFO:tensorflow:Assets written to: data/models/model_cnn_100epochs_noaugment_XR_WRIST/assets
#
# Evaluate model
#
# Test accuracy: 49.92 %
# Test F1 score: 39.78 %
# Test Precision score: 43.08 %
# Test Recall score: 36.95 %
# 21/21 [==============================] - 8s 373ms/step - loss: 1.3456 - binary_accuracy: 0.6692
# 275/275 [==============================] - 110s 398ms/step - loss: 0.0815 - binary_accuracy: 0.9777
# 31/31 [==============================] - 12s 389ms/step - loss: 1.2585 - binary_accuracy: 0.6592
# Delete model
# XR_FINGER
#
# Build model
#
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 320, 320, 3)]     0
# _________________________________________________________________
# Conv2D-1 (Conv2D)            (None, 320, 320, 16)      448
# _________________________________________________________________
# MaxPool2D-1 (MaxPooling2D)   (None, 160, 160, 16)      0
# _________________________________________________________________
# Dropout-1 (Dropout)          (None, 160, 160, 16)      0
# _________________________________________________________________
# Conv2D-2 (Conv2D)            (None, 160, 160, 32)      4640
# _________________________________________________________________
# MaxPool2D-2 (MaxPooling2D)   (None, 80, 80, 32)        0
# _________________________________________________________________
# Dropout-2 (Dropout)          (None, 80, 80, 32)        0
# _________________________________________________________________
# Conv2D-3 (Conv2D)            (None, 80, 80, 64)        18496
# _________________________________________________________________
# MaxPool2D-3 (MaxPooling2D)   (None, 40, 40, 64)        0
# _________________________________________________________________
# Dropout-3 (Dropout)          (None, 40, 40, 64)        0
# _________________________________________________________________
# Conv2D-4 (Conv2D)            (None, 40, 40, 128)       73856
# _________________________________________________________________
# MaxPool2D-4 (MaxPooling2D)   (None, 20, 20, 128)       0
# _________________________________________________________________
# Dropout-4 (Dropout)          (None, 20, 20, 128)       0
# _________________________________________________________________
# Flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# Dense-1 (Dense)              (None, 100)               5120100
# _________________________________________________________________
# Dropout-5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 101
# =================================================================
# Total params: 5,217,641
# Trainable params: 5,217,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Train model
#
# XR_FINGER
# Using validation_steps = 16
# Using steps_per_epoch = 144
# Epoch 1/100
# 144/144 [==============================] - 297s 2s/step - loss: 0.8236 - binary_accuracy: 0.5839 - val_loss: 0.6969 - val_binary_accuracy: 0.5848
# Epoch 2/100
# 144/144 [==============================] - 304s 2s/step - loss: 0.5787 - binary_accuracy: 0.6557 - val_loss: 0.6749 - val_binary_accuracy: 0.5848
# Epoch 3/100
# 144/144 [==============================] - 319s 2s/step - loss: 0.5751 - binary_accuracy: 0.6767 - val_loss: 0.6836 - val_binary_accuracy: 0.6068
# Epoch 4/100
# 144/144 [==============================] - 314s 2s/step - loss: 0.5458 - binary_accuracy: 0.7088 - val_loss: 0.7158 - val_binary_accuracy: 0.6327
# Epoch 5/100
# 144/144 [==============================] - 304s 2s/step - loss: 0.4967 - binary_accuracy: 0.7483 - val_loss: 0.7612 - val_binary_accuracy: 0.6287
# Epoch 6/100
# 144/144 [==============================] - 309s 2s/step - loss: 0.4354 - binary_accuracy: 0.7849 - val_loss: 0.7136 - val_binary_accuracy: 0.6527
# Epoch 7/100
# 144/144 [==============================] - 299s 2s/step - loss: 0.3662 - binary_accuracy: 0.8205 - val_loss: 0.8509 - val_binary_accuracy: 0.6407
# Epoch 8/100
# 144/144 [==============================] - 299s 2s/step - loss: 0.3175 - binary_accuracy: 0.8534 - val_loss: 0.9351 - val_binary_accuracy: 0.6248
# Epoch 9/100
# 144/144 [==============================] - 316s 2s/step - loss: 0.2403 - binary_accuracy: 0.8998 - val_loss: 1.3833 - val_binary_accuracy: 0.6267
# Epoch 10/100
# 144/144 [==============================] - 311s 2s/step - loss: 0.1923 - binary_accuracy: 0.9162 - val_loss: 1.3159 - val_binary_accuracy: 0.6267
# Epoch 00010: early stopping
#
# Save training history
#
#
# Save model
#
# INFO:tensorflow:Assets written to: data/models/model_cnn_100epochs_noaugment_XR_FINGER/assets
#
# Evaluate model
#
# Test accuracy: 46.42 %
# Test F1 score: 43.22 %
# Test Precision score: 50.0 %
# Test Recall score: 38.06 %
# 15/15 [==============================] - 5s 348ms/step - loss: 1.3751 - binary_accuracy: 0.6421
# 144/144 [==============================] - 52s 360ms/step - loss: 0.1401 - binary_accuracy: 0.9524
# 16/16 [==============================] - 6s 331ms/step - loss: 1.3159 - binary_accuracy: 0.6267
# Delete model
# XR_ELBOW
#
# Build model
#
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 320, 320, 3)]     0
# _________________________________________________________________
# Conv2D-1 (Conv2D)            (None, 320, 320, 16)      448
# _________________________________________________________________
# MaxPool2D-1 (MaxPooling2D)   (None, 160, 160, 16)      0
# _________________________________________________________________
# Dropout-1 (Dropout)          (None, 160, 160, 16)      0
# _________________________________________________________________
# Conv2D-2 (Conv2D)            (None, 160, 160, 32)      4640
# _________________________________________________________________
# MaxPool2D-2 (MaxPooling2D)   (None, 80, 80, 32)        0
# _________________________________________________________________
# Dropout-2 (Dropout)          (None, 80, 80, 32)        0
# _________________________________________________________________
# Conv2D-3 (Conv2D)            (None, 80, 80, 64)        18496
# _________________________________________________________________
# MaxPool2D-3 (MaxPooling2D)   (None, 40, 40, 64)        0
# _________________________________________________________________
# Dropout-3 (Dropout)          (None, 40, 40, 64)        0
# _________________________________________________________________
# Conv2D-4 (Conv2D)            (None, 40, 40, 128)       73856
# _________________________________________________________________
# MaxPool2D-4 (MaxPooling2D)   (None, 20, 20, 128)       0
# _________________________________________________________________
# Dropout-4 (Dropout)          (None, 20, 20, 128)       0
# _________________________________________________________________
# Flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# Dense-1 (Dense)              (None, 100)               5120100
# _________________________________________________________________
# Dropout-5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 101
# =================================================================
# Total params: 5,217,641
# Trainable params: 5,217,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Train model
#
# XR_ELBOW
# Using validation_steps = 16
# Using steps_per_epoch = 139
# Epoch 1/100
# 139/139 [==============================] - 297s 2s/step - loss: 0.7490 - binary_accuracy: 0.5709 - val_loss: 0.6479 - val_binary_accuracy: 0.5902
# Epoch 2/100
# 139/139 [==============================] - 298s 2s/step - loss: 0.6589 - binary_accuracy: 0.5948 - val_loss: 0.6502 - val_binary_accuracy: 0.5902
# Epoch 3/100
# 139/139 [==============================] - 298s 2s/step - loss: 0.6482 - binary_accuracy: 0.6112 - val_loss: 0.6469 - val_binary_accuracy: 0.6004
# Epoch 4/100
# 139/139 [==============================] - 289s 2s/step - loss: 0.6345 - binary_accuracy: 0.6346 - val_loss: 0.6476 - val_binary_accuracy: 0.6311
# Epoch 5/100
# 139/139 [==============================] - 302s 2s/step - loss: 0.6128 - binary_accuracy: 0.6582 - val_loss: 0.6629 - val_binary_accuracy: 0.6209
# Epoch 6/100
# 139/139 [==============================] - 302s 2s/step - loss: 0.5863 - binary_accuracy: 0.6894 - val_loss: 0.6637 - val_binary_accuracy: 0.6209
# Epoch 7/100
# 139/139 [==============================] - 295s 2s/step - loss: 0.5408 - binary_accuracy: 0.7221 - val_loss: 0.6976 - val_binary_accuracy: 0.5902
# Epoch 8/100
# 139/139 [==============================] - 307s 2s/step - loss: 0.4996 - binary_accuracy: 0.7544 - val_loss: 0.6984 - val_binary_accuracy: 0.6455
# Epoch 9/100
# 139/139 [==============================] - 297s 2s/step - loss: 0.4289 - binary_accuracy: 0.7985 - val_loss: 0.7912 - val_binary_accuracy: 0.6270
# Epoch 10/100
# 139/139 [==============================] - 297s 2s/step - loss: 0.3701 - binary_accuracy: 0.8201 - val_loss: 0.7665 - val_binary_accuracy: 0.6230
# Epoch 11/100
# 139/139 [==============================] - 304s 2s/step - loss: 0.3073 - binary_accuracy: 0.8632 - val_loss: 1.0368 - val_binary_accuracy: 0.6291
# Epoch 00011: early stopping
#
# Save training history
#
#
# Save model
#
# INFO:tensorflow:Assets written to: data/models/model_cnn_100epochs_noaugment_XR_ELBOW/assets
#
# Evaluate model
#
# Test accuracy: 49.25 %
# Test F1 score: 36.9 %
# Test Precision score: 47.92 %
# Test Recall score: 30.0 %
# 15/15 [==============================] - 6s 389ms/step - loss: 1.3163 - binary_accuracy: 0.5484
# 139/139 [==============================] - 59s 420ms/step - loss: 0.2022 - binary_accuracy: 0.9226
# 16/16 [==============================] - 6s 395ms/step - loss: 1.0368 - binary_accuracy: 0.6291
# Delete model

# %%
def plot_learning(history, bodypart):

  fig1  = plt.figure(figsize=(8,4), dpi = 150)

  # summarize history for accuracy
  plt.plot(history.history['binary_accuracy'], c = 'm')
  plt.plot(history.history['val_binary_accuracy'], "--", c = 'c')
  plt.title('Model accuracy for CNN: ' + bodypart, fontsize=16)
  plt.ylabel('accuracy', fontsize=16)
  plt.xlabel('epoch', fontsize=16)
  plt.legend(['train', 'validation'], 
             loc='upper right', 
             fontsize=16)
  # plt.savefig('model_accuracy_cnn_' + bodypart + '.png')
  # files.download('model_accuracy_cnn_' + bodypart + '.png')
  matplotlib.rc('xtick', labelsize=16) 
  matplotlib.rc('ytick', labelsize=16) 

  plt.show()
  plt.savefig('data/plots/accuracy_model_cnn_100epochs_noaugment'+bodypart+'.png')
  plt.clf()
    
  fig2  = plt.figure(figsize=(8,4), dpi = 150)

  # summarize history for loss
  plt.plot(history.history['loss'], c = 'm')
  plt.plot(history.history['val_loss'], "--",  c = 'c')
  plt.title('Model loss for CNN: ' + bodypart, fontsize=16)
  plt.ylabel('loss', fontsize=16)
  plt.xlabel('epoch', fontsize=16)
  plt.legend(['train', 'validation'], 
             loc='upper right', 
             fontsize=16)
  # plt.savefig('model_loss_cnn_' + bodypart + '.png')
  # files.download("model_loss_cnn_" + bodypart + '.png')
  matplotlib.rc('xtick', labelsize=16) 
  matplotlib.rc('ytick', labelsize=16) 
    

  plt.show()
  plt.savefig('data/plots/loss_model_cnn_100epochs_noaugment'+bodypart+'.png')
  plt.clf()

# %%
for bodypart in set(train.bodypart):
    print('-----------')
    print(bodypart)
    plot_learning(histories_cnn[bodypart], 
                  bodypart)
# Out:
# -----------
# XR_FOREARM
# -----------
# XR_HAND
# -----------
# XR_HUMERUS
# -----------
# XR_SHOULDER
# -----------
# XR_WRIST
# -----------
# XR_FINGER
# -----------
# XR_ELBOW

# %% [markdown]
# **RUN UP HERE**

# %% [markdown]
# # CNN with pre-trained model

# %% [markdown]
# ## DenseNet

# %% [markdown]
# ### Build

# %%
# add model on top
def build_model_on_densenet():
  # DenseNet model
  densenet_model = tf.keras.applications.DenseNet121(weights='imagenet',
                                                    input_shape = (320,320,3),
                                                    include_top = False)
  densenet_model.trainable = False
  # add new model on top
  inputs = tf.keras.Input(shape=(320,320,3))
  x = densenet_model(inputs, 
                    training=False)
  x = tf.keras.layers.GlobalAveragePooling2D()(x)
  x = tf.keras.layers.Dropout(0.2)(x)
  outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
  model = tf.keras.Model(inputs, outputs)
  model.summary()

  # train the top layer
  model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3),
                loss = 'binary_crossentropy',
                metrics = ['binary_accuracy'])
  return model

# %% [markdown]
# ### Train

# %%
callbacks_2 = tf.keras.callbacks.EarlyStopping(monitor='val_binary_accuracy', 
                                             patience=8,
                                             restore_best_weights=True)

def train_model(model, bodypart):
    validation_steps = math.ceil(valid_generators[bodypart].n/ valid_generators[bodypart].batch_size)
    print("Using validation_steps = %d" % validation_steps)
    steps_per_epoch = math.ceil(train_generators[bodypart].n / (train_generators[bodypart].batch_size))
    print("Using steps_per_epoch = %d" % steps_per_epoch)

    history = model.fit(train_generators[bodypart],
                        validation_data = valid_generators[bodypart],
                        validation_steps = validation_steps,
                        steps_per_epoch = steps_per_epoch,
                        epochs=100,
                        verbose=1,
                        callbacks=[callbacks_2]
    )
    return history

# %%
def clean_up(model):
    K.clear_session()
    del model
    gc.collect()

# %%
M

# %% [markdown]
# ## Done

# %%
des_done = ['XR_FOREARM', 
       'XR_HUMERUS',
       'XR_SHOULDER',
       'XR_WRIST']

# %%
import json
densenet_model_top_histories_reloaded = {}
for bodypart in des_done:
    url = "data/history/history_densenet_model_top_model_100epochs_noaugment_"+bodypart+".json"
    f = open(url)
    densenet_model_top_histories_reloaded[bodypart] = json.load(f)

for bodypart in des_done:
    plot_learning_curves.plot_history_from_dict(densenet_model_top_histories_reloaded[bodypart], 
                                     bodypart,
                                     'densenet_model_top',
                                     100,
                                     data_augmentation='no_augment')

# %%
for bodypart in des_done:
    print("\nLoad model\n")        
    model = keras.models.load_model('data/models/densenet_model_top_100epochs_noaugment_'+bodypart+'.h5') 
    model.evaluate(test_generators[bodypart], verbose=1)
    model.evaluate(train_generators[bodypart], verbose=1)
    model.evaluate(valid_generators[bodypart], verbose=1)
    print("Delete model")
    clean_up(model)
# Out:
# Load model
#
# 10/10 [==============================] - 52s 5s/step - loss: 0.5289 - binary_accuracy: 0.7309
# 52/52 [==============================] - 216s 4s/step - loss: 0.4462 - binary_accuracy: 0.8156
# 6/6 [==============================] - 23s 4s/step - loss: 0.4130 - binary_accuracy: 0.8182
# Delete model
#
# Load model
#
# 9/9 [==============================] - 35s 3s/step - loss: 0.4506 - binary_accuracy: 0.8021
# 36/36 [==============================] - 124s 3s/step - loss: 0.4618 - binary_accuracy: 0.8257
# 5/5 [==============================] - 15s 3s/step - loss: 0.5472 - binary_accuracy: 0.7385
# Delete model
#
# Load model
#
# 18/18 [==============================] - 64s 3s/step - loss: 0.5590 - binary_accuracy: 0.7052
# 236/236 [==============================] - 958s 4s/step - loss: 0.5499 - binary_accuracy: 0.7289
# 27/27 [==============================] - 125s 5s/step - loss: 0.5257 - binary_accuracy: 0.7556
# Delete model
#
# Load model
#
# 21/21 [==============================] - 101s 5s/step - loss: 0.4768 - binary_accuracy: 0.7815
# 275/275 [==============================] - 1291s 5s/step - loss: 0.4434 - binary_accuracy: 0.8061
# 30/30 [==============================] - 134s 4s/step - loss: 0.4546 - binary_accuracy: 0.8067
# Delete model

# %% [markdown]
# ## Pending

# %%
pending = ['XR_ELBOW',
           'XR_FINGER', 
           'XR_HAND']

# %%
densenet_model_top_histories = {}

for bodypart in pending:
    print(bodypart)   
    print("\nBuild model\n")
    model = build_model_on_densenet()
    print('\nTrain model\n')
    print(bodypart)
    densenet_model_top_histories[bodypart] = train_model(model, 
                                                         bodypart)
    print('\nSave training history\n')
    with open("data/history/history_densenet_model_top_model_100epochs_noaugment_"+bodypart+".json", "w") as file:
        json.dump(densenet_model_top_histories[bodypart].history, file)
        print('\nSave model\n')
    model.save("data/models/densenet_model_top_100epochs_noaugment_"+bodypart)
    model.save("data/models/densenet_model_top_100epochs_noaugment_"+bodypart+".h5")
    print('\nEvaluate model\n')
    eval_func(test[test['bodypart'] == bodypart]['class'], 
                    model.predict(test_generators[bodypart]))
    model.evaluate(test_generators[bodypart], verbose=1)
    model.evaluate(train_generators[bodypart], verbose=1)
    model.evaluate(valid_generators[bodypart], verbose=1)
    print("Delete model")
    clean_up(model)
# Out:
# XR_ELBOW
#
# Build model
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 320, 320, 3)]     0
# _________________________________________________________________
# densenet121 (Functional)     (None, 10, 10, 1024)      7037504
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 7,038,529
# Trainable params: 1,025
# Non-trainable params: 7,037,504
# _________________________________________________________________
#
# Train model
#
# XR_ELBOW
# Using validation_steps = 16
# Using steps_per_epoch = 139
# Epoch 1/100
# 139/139 [==============================] - 734s 5s/step - loss: 0.7018 - binary_accuracy: 0.5683 - val_loss: 0.5904 - val_binary_accuracy: 0.7083
# Epoch 2/100
# 139/139 [==============================] - 698s 5s/step - loss: 0.5984 - binary_accuracy: 0.6969 - val_loss: 0.5512 - val_binary_accuracy: 0.7341
# Epoch 3/100
# 139/139 [==============================] - 727s 5s/step - loss: 0.5726 - binary_accuracy: 0.7213 - val_loss: 0.5327 - val_binary_accuracy: 0.7619
# Epoch 4/100
# 139/139 [==============================] - 706s 5s/step - loss: 0.5601 - binary_accuracy: 0.7306 - val_loss: 0.5290 - val_binary_accuracy: 0.7560
# Epoch 5/100
# 139/139 [==============================] - 685s 5s/step - loss: 0.5651 - binary_accuracy: 0.7240 - val_loss: 0.5171 - val_binary_accuracy: 0.7698
# Epoch 6/100
# 139/139 [==============================] - 675s 5s/step - loss: 0.5347 - binary_accuracy: 0.7559 - val_loss: 0.5167 - val_binary_accuracy: 0.7778
# Epoch 7/100
# 139/139 [==============================] - 668s 5s/step - loss: 0.5265 - binary_accuracy: 0.7551 - val_loss: 0.5077 - val_binary_accuracy: 0.7877
# Epoch 8/100
# 139/139 [==============================] - 718s 5s/step - loss: 0.5312 - binary_accuracy: 0.7460 - val_loss: 0.5049 - val_binary_accuracy: 0.7698
# Epoch 9/100
# 139/139 [==============================] - 732s 5s/step - loss: 0.5420 - binary_accuracy: 0.7375 - val_loss: 0.5030 - val_binary_accuracy: 0.7778
# Epoch 10/100
# 139/139 [==============================] - 739s 5s/step - loss: 0.5311 - binary_accuracy: 0.7419 - val_loss: 0.5130 - val_binary_accuracy: 0.7639
# Epoch 11/100
# 139/139 [==============================] - 688s 5s/step - loss: 0.5132 - binary_accuracy: 0.7516 - val_loss: 0.5104 - val_binary_accuracy: 0.7659
# Epoch 12/100
# 139/139 [==============================] - 578s 4s/step - loss: 0.5234 - binary_accuracy: 0.7554 - val_loss: 0.5020 - val_binary_accuracy: 0.7698
# Epoch 13/100
# 139/139 [==============================] - 617s 4s/step - loss: 0.5202 - binary_accuracy: 0.7576 - val_loss: 0.4967 - val_binary_accuracy: 0.7798
# Epoch 14/100
# 139/139 [==============================] - 640s 5s/step - loss: 0.5152 - binary_accuracy: 0.7627 - val_loss: 0.4949 - val_binary_accuracy: 0.7798
# Epoch 15/100
# 139/139 [==============================] - 605s 4s/step - loss: 0.5193 - binary_accuracy: 0.7651 - val_loss: 0.4938 - val_binary_accuracy: 0.7817
#
# Save training history
#
#
# Save model
#
# INFO:tensorflow:Assets written to: data/models/densenet_model_top_100epochs_noaugment_XR_ELBOW/assets
#
# Evaluate model
#
# Test accuracy: 50.97 %
# Test F1 score: 38.71 %
# Test Precision score: 50.7 %
# Test Recall score: 31.3 %
# 15/15 [==============================] - 62s 4s/step - loss: 0.5098 - binary_accuracy: 0.7591
# 139/139 [==============================] - 607s 4s/step - loss: 0.5121 - binary_accuracy: 0.7669
# 16/16 [==============================] - 64s 4s/step - loss: 0.5077 - binary_accuracy: 0.7877
# Delete model
# XR_FINGER
#
# Build model
#
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 320, 320, 3)]     0
# _________________________________________________________________
# densenet121 (Functional)     (None, 10, 10, 1024)      7037504
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1025
# =================================================================
# Total params: 7,038,529
# Trainable params: 1,025
# Non-trainable params: 7,037,504
# _________________________________________________________________
#
# Train model
#
# XR_FINGER
# Using validation_steps = 17
# Using steps_per_epoch = 144
# Epoch 1/100
# 144/144 [==============================] - 728s 5s/step - loss: 0.7619 - binary_accuracy: 0.5513 - val_loss: 0.6204 - val_binary_accuracy: 0.6202
# Epoch 2/100
# 144/144 [==============================] - 721s 5s/step - loss: 0.5865 - binary_accuracy: 0.6754 - val_loss: 0.5960 - val_binary_accuracy: 0.6628
# Epoch 3/100
# 144/144 [==============================] - 730s 5s/step - loss: 0.5596 - binary_accuracy: 0.6914 - val_loss: 0.5739 - val_binary_accuracy: 0.6705
# Epoch 4/100
# 144/144 [==============================] - 724s 5s/step - loss: 0.5492 - binary_accuracy: 0.7136 - val_loss: 0.5734 - val_binary_accuracy: 0.6938
# Epoch 5/100
# 144/144 [==============================] - 633s 4s/step - loss: 0.5266 - binary_accuracy: 0.7353 - val_loss: 0.5547 - val_binary_accuracy: 0.6822
# Epoch 6/100
# 144/144 [==============================] - 572s 4s/step - loss: 0.5278 - binary_accuracy: 0.7229 - val_loss: 0.5577 - val_binary_accuracy: 0.6957
# Epoch 7/100
# 144/144 [==============================] - 595s 4s/step - loss: 0.5227 - binary_accuracy: 0.7400 - val_loss: 0.5558 - val_binary_accuracy: 0.6938
# Epoch 8/100
# 144/144 [==============================] - 622s 4s/step - loss: 0.5260 - binary_accuracy: 0.7392 - val_loss: 0.5671 - val_binary_accuracy: 0.7112
# Epoch 9/100
# 144/144 [==============================] - 679s 5s/step - loss: 0.5196 - binary_accuracy: 0.7288 - val_loss: 0.5495 - val_binary_accuracy: 0.7035
# Epoch 10/100
# 144/144 [==============================] - 650s 5s/step - loss: 0.5251 - binary_accuracy: 0.7314 - val_loss: 0.5410 - val_binary_accuracy: 0.7112
# Epoch 11/100
# 144/144 [==============================] - 646s 4s/step - loss: 0.5131 - binary_accuracy: 0.7460 - val_loss: 0.5394 - val_binary_accuracy: 0.7035
# Epoch 12/100
# 144/144 [==============================] - 647s 4s/step - loss: 0.5142 - binary_accuracy: 0.7423 - val_loss: 0.5411 - val_binary_accuracy: 0.7074
# Epoch 13/100
# 144/144 [==============================] - 612s 4s/step - loss: 0.5157 - binary_accuracy: 0.7332 - val_loss: 0.5332 - val_binary_accuracy: 0.7190
# Epoch 14/100
# 144/144 [==============================] - 637s 4s/step - loss: 0.5027 - binary_accuracy: 0.7490 - val_loss: 0.5448 - val_binary_accuracy: 0.7093
# Epoch 15/100
# 144/144 [==============================] - 685s 5s/step - loss: 0.4940 - binary_accuracy: 0.7532 - val_loss: 0.5343 - val_binary_accuracy: 0.7132
# Epoch 16/100
# 144/144 [==============================] - 713s 5s/step - loss: 0.5205 - binary_accuracy: 0.7356 - val_loss: 0.5347 - val_binary_accuracy: 0.7190
# Epoch 17/100
# 144/144 [==============================] - 663s 5s/step - loss: 0.5173 - binary_accuracy: 0.7391 - val_loss: 0.5443 - val_binary_accuracy: 0.7132
# Epoch 18/100
# 144/144 [==============================] - 651s 5s/step - loss: 0.5072 - binary_accuracy: 0.7449 - val_loss: 0.5528 - val_binary_accuracy: 0.7190
# Epoch 19/100
# 144/144 [==============================] - 630s 4s/step - loss: 0.5045 - binary_accuracy: 0.7443 - val_loss: 0.5392 - val_binary_accuracy: 0.7054
# Epoch 20/100
# 144/144 [==============================] - 649s 5s/step - loss: 0.5115 - binary_accuracy: 0.7425 - val_loss: 0.5338 - val_binary_accuracy: 0.7132
# Epoch 21/100
# 144/144 [==============================] - 694s 5s/step - loss: 0.5106 - binary_accuracy: 0.7348 - val_loss: 0.5323 - val_binary_accuracy: 0.7229
# Epoch 22/100
# 144/144 [==============================] - 714s 5s/step - loss: 0.5163 - binary_accuracy: 0.7372 - val_loss: 0.5467 - val_binary_accuracy: 0.7171
# Epoch 23/100
# 144/144 [==============================] - 669s 5s/step - loss: 0.5038 - binary_accuracy: 0.7433 - val_loss: 0.5327 - val_binary_accuracy: 0.7151
# Epoch 24/100
# 144/144 [==============================] - 663s 5s/step - loss: 0.4898 - binary_accuracy: 0.7620 - val_loss: 0.5323 - val_binary_accuracy: 0.7345
# Epoch 25/100
# 144/144 [==============================] - 622s 4s/step - loss: 0.4936 - binary_accuracy: 0.7639 - val_loss: 0.5513 - val_binary_accuracy: 0.7151
# Epoch 26/100
# 144/144 [==============================] - 661s 5s/step - loss: 0.4904 - binary_accuracy: 0.7588 - val_loss: 0.5499 - val_binary_accuracy: 0.7229
# Epoch 27/100
# 144/144 [==============================] - 704s 5s/step - loss: 0.4953 - binary_accuracy: 0.7618 - val_loss: 0.5402 - val_binary_accuracy: 0.7267
# Epoch 28/100
# 144/144 [==============================] - 760s 5s/step - loss: 0.4950 - binary_accuracy: 0.7483 - val_loss: 0.5274 - val_binary_accuracy: 0.7248
# Epoch 29/100
# 144/144 [==============================] - 785s 5s/step - loss: 0.5081 - binary_accuracy: 0.7571 - val_loss: 0.5279 - val_binary_accuracy: 0.7209
# Epoch 30/100
# 144/144 [==============================] - 765s 5s/step - loss: 0.4910 - binary_accuracy: 0.7677 - val_loss: 0.5410 - val_binary_accuracy: 0.7267
# Epoch 31/100
# 144/144 [==============================] - 718s 5s/step - loss: 0.4928 - binary_accuracy: 0.7533 - val_loss: 0.5562 - val_binary_accuracy: 0.7267
# Epoch 32/100
# 144/144 [==============================] - 733s 5s/step - loss: 0.4987 - binary_accuracy: 0.7594 - val_loss: 0.5323 - val_binary_accuracy: 0.7229
#
# Save training history
#
#
# Save model
#
# INFO:tensorflow:Assets written to: data/models/densenet_model_top_100epochs_noaugment_XR_FINGER/assets
#
# Evaluate model
#
# Test accuracy: 47.72 %
# Test F1 score: 40.2 %
# Test Precision score: 51.92 %
# Test Recall score: 32.79 %
# 15/15 [==============================] - 73s 5s/step - loss: 0.6120 - binary_accuracy: 0.6898
# 144/144 [==============================] - 671s 5s/step - loss: 0.4749 - binary_accuracy: 0.7710
# 17/17 [==============================] - 83s 5s/step - loss: 0.5323 - binary_accuracy: 0.7345
# Delete model
# XR_HAND
#
# Build model
#
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 320, 320, 3)]     0
# _________________________________________________________________
# densenet121 (Functional)     (None, 10, 10, 1024)      7037504
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1025
# =================================================================
# Total params: 7,038,529
# Trainable params: 1,025
# Non-trainable params: 7,037,504
# _________________________________________________________________
#
# Train model
#
# XR_HAND
# Using validation_steps = 17
# Using steps_per_epoch = 157
# Epoch 1/100
# 157/157 [==============================] - 779s 5s/step - loss: 0.6347 - binary_accuracy: 0.6955 - val_loss: 0.5416 - val_binary_accuracy: 0.7584
# Epoch 2/100
# 157/157 [==============================] - 734s 5s/step - loss: 0.5796 - binary_accuracy: 0.7203 - val_loss: 0.5190 - val_binary_accuracy: 0.7565
# Epoch 3/100
# 157/157 [==============================] - 667s 4s/step - loss: 0.5616 - binary_accuracy: 0.7393 - val_loss: 0.5101 - val_binary_accuracy: 0.7732
# Epoch 4/100
# 157/157 [==============================] - 679s 4s/step - loss: 0.5428 - binary_accuracy: 0.7428 - val_loss: 0.5067 - val_binary_accuracy: 0.7993
# Epoch 5/100
# 157/157 [==============================] - 677s 4s/step - loss: 0.5287 - binary_accuracy: 0.7575 - val_loss: 0.5024 - val_binary_accuracy: 0.8104
# Epoch 6/100
# 157/157 [==============================] - 764s 5s/step - loss: 0.5275 - binary_accuracy: 0.7548 - val_loss: 0.4964 - val_binary_accuracy: 0.7918
# Epoch 7/100
# 157/157 [==============================] - 789s 5s/step - loss: 0.5285 - binary_accuracy: 0.7506 - val_loss: 0.4981 - val_binary_accuracy: 0.8104
# Epoch 8/100
# 157/157 [==============================] - 779s 5s/step - loss: 0.5304 - binary_accuracy: 0.7538 - val_loss: 0.4915 - val_binary_accuracy: 0.7862
# Epoch 9/100
# 157/157 [==============================] - 751s 5s/step - loss: 0.5311 - binary_accuracy: 0.7501 - val_loss: 0.4932 - val_binary_accuracy: 0.7862
# Epoch 10/100
# 157/157 [==============================] - 772s 5s/step - loss: 0.5216 - binary_accuracy: 0.7654 - val_loss: 0.4905 - val_binary_accuracy: 0.8048
# Epoch 11/100
# 157/157 [==============================] - 765s 5s/step - loss: 0.5359 - binary_accuracy: 0.7433 - val_loss: 0.5017 - val_binary_accuracy: 0.7695
# Epoch 12/100
# 157/157 [==============================] - 735s 5s/step - loss: 0.5160 - binary_accuracy: 0.7639 - val_loss: 0.4861 - val_binary_accuracy: 0.8067
# Epoch 13/100
# 157/157 [==============================] - 726s 5s/step - loss: 0.5168 - binary_accuracy: 0.7636 - val_loss: 0.4880 - val_binary_accuracy: 0.8086
#
# Save training history
#
#
# Save model
#
# INFO:tensorflow:Assets written to: data/models/densenet_model_top_100epochs_noaugment_XR_HAND/assets
#
# Evaluate model
#
# Test accuracy: 55.65 %
# Test F1 score: 12.07 %
# Test Precision score: 32.56 %
# Test Recall score: 7.41 %
# 15/15 [==============================] - 64s 4s/step - loss: 0.5935 - binary_accuracy: 0.6478
# 157/157 [==============================] - 665s 4s/step - loss: 0.5190 - binary_accuracy: 0.7626
# 17/17 [==============================] - 75s 4s/step - loss: 0.5024 - binary_accuracy: 0.8104
# Delete model

# %%
for bodypart in pending:
    print(bodypart)
    plot_learning_curves.plot_history(densenet_model_top_histories[bodypart], 
                                      bodypart,
                                        'densenet_model_top',
                                        100,
                                        data_augmentation='no_augment')
# Out:
# XR_ELBOW
# XR_FINGER
# XR_HAND

# %%
# densenet_model_top_histories = {}

# for bodypart in set(train.bodypart):
#     print(bodypart)
#     print("\nBuild model\n")
#     model = build_model_on_densenet()
#     print('\nTrain model\n')
#     print(bodypart)
#     densenet_model_top_histories[bodypart] = train_model(model, 
#                                                          bodypart)
#     print('\nSave training history\n')
#     with open("data/history/history_densenet_model_top_model_100epochs_noaugment_"+bodypart+".json", "w") as file:
#         json.dump(densenet_model_top_histories[bodypart].history, file)
#         print('\nSave model\n')
#     model.save("data/models/densenet_model_top_100epochs_noaugment_"+bodypart)
#     model.save("data/models/densenet_model_top_100epochs_noaugment_"+bodypart+".h5")
#     print('\nEvaluate model\n')
#     eval_func(test[test['bodypart'] == bodypart]['class'], 
#                     model.predict(test_generators[bodypart]))
#     model.evaluate(test_generators[bodypart], verbose=1)
#     print("Delete model")
#     clean_up(model)
