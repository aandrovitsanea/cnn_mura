# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img
import os
import lib.data_loader as data_loader
import models.base_model as base_model

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import math
import matplotlib.image as mpimg
# from tqdm import tqdm
from PIL import Image
import tensorflow as tf
from tensorflow import keras
import random, os
import numpy as np
import pandas as pd
# import cv2
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
#%matplotlib inline
from mpl_toolkits.axes_grid1 import make_axes_locatable
from glob import glob
import gc
# from skimage.transform import resize

from tensorflow.keras import backend as K # Importing Keras backend (by default it is Tensorflow)
from tensorflow.keras.layers import Input, Conv2D, Dense, Dropout, Flatten, MaxPool2D # Layers to be used for building our model
from tensorflow.keras.models import Model # The class used to create a model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.random import set_seed

from sklearn.metrics import f1_score, recall_score, precision_score

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
#! pip install -q -U keras-tuner
import keras_tuner as kt

import json

from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.4.0
# Train model
# Tensorflow version 2.4.0

# %% [markdown]
# # Data

# %%
train_generators, valid_generators, test_generators, test = data_loader.load_all("deep_augment")
# Out:
# Import train and test data
#
# Doing a light data augmentation
#
# Create training, validation and test set
#
# Found 33080 validated image filenames.
# Found 3728 validated image filenames.
# Found 3197 validated image filenames.
# Data munging completed

# %% [markdown]
# # Fine tuning

# %%
def model_builder_cnn(hp, conv_dropout=True):

    #########################################
    ## set hyperparameters for fine tuning ##
    #########################################

    # tune the number of units
    hp_units = hp.Int('units', min_value=32, max_value=32*8, step=32)
    
    # tune the learning rate for the optimizer
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    optimizer = keras.optimizers.Adam(learning_rate=hp_learning_rate)

    # convulational layers
    conv_layers = hp.Int('conv_blocks', 2, 5, default=3)

    # dropour rate
    dropout_rate = hp.Float('dropout', 0, 0.5, step=0.1, default=0.2)

    np.random.seed(1000) # Define the seed for numpy to have reproducible experiments.
    set_seed(150) # Define the seed for Tensorflow to have reproducible experiments.

    ###################
    ## define model ##
    ###################
    input_shape = (320,320,3)
    
    # define the input layer
    input = Input(
        shape=input_shape,
        name='Input'
    )

    x = input
    # define the convolutional layers
    # using functional api
    for i in range(conv_layers):
        # filters
        filters = hp.Int('filters_' + str(i), 32, 224, step=32)

        x = Conv2D(
            filters=filters,
            kernel_size=(3, 3),
            strides=(1, 1),
            padding='same',
            dilation_rate=(1, 1),
            activation=tf.keras.layers.ReLU(),
            name='Conv2D-{0:d}'.format(i + 1)
        )(x)

        x = MaxPool2D(
            pool_size=(2, 2),
            strides=(2, 2),
            padding='same',
            name='MaxPool2D-{0:d}'.format(i + 1)
        )(x)

        if conv_dropout:
            x = Dropout(
                rate = dropout_rate,
                name='Dropout-{0:d}'.format(i + 1)
            )(x)

    # flatten the convolved images 
    # fit to feed the dense layer
    x = Flatten(name='Flatten')(x)
    
    # define the output layer
    output = Dense(
        units = classes,
        activation = 'softmax',
        name='Output'
    )(x)

    # define the model and train it
    model_cnn = Model(inputs=input, 
                      outputs=output)

    model_cnn.compile(
                      optimizer=optimizer, 
                      loss='sparse_categorical_crossentropy', 
                      metrics=['accuracy'])
    
    return model_cnn

# %%
# build tuner to fine-tune the hyper-parameters
# for the model
classes=14
tuner = kt.Hyperband(
                    model_builder_cnn,
                    objective='val_accuracy',
                    max_epochs=30,
                    hyperband_iterations=2,
                    directory='data/fine_tuner_1stproject',
                    project_name='base_model_30_epochs'
)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project data/fine_tuner_1stproject/base_model_30_epochs/oracle.json
# INFO:tensorflow:Reloading Tuner from data/fine_tuner_1stproject/base_model_30_epochs/tuner0.json

# %%
# define the early stopping
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                              patience=5)

# perfrom search for best parameters
tuner.search(train_generators, 
             validation_data=valid_generators, 
             epochs=30, 
             callbacks=[stop_early],
             validation_steps=4,
             steps_per_epoch=10)

# get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
# Out:
# Trial 160 Complete [00h 07m 26s]
# val_accuracy: 0.1796875
#
# Best val_accuracy So Far: 0.375
# Total elapsed time: 01h 34m 19s
#
# Search: Running Trial #161
#
# Value             |Best Value So Far |Hyperparameter
# 128               |160               |units
# 0.0001            |0.001             |learning_rate
# 4                 |4                 |conv_blocks
# 0.1               |0                 |dropout
# 224               |160               |filters_0
# 160               |160               |filters_1
# 96                |64                |filters_2
# 32                |160               |filters_3
# 128               |None              |filters_4
# 10                |30                |tuner/epochs
# 4                 |10                |tuner/initial_epoch
# 2                 |3                 |tuner/bracket
# 1                 |3                 |tuner/round
# 0154              |0047              |tuner/trial_id
#
# Epoch 5/10
# 10/10 [==============================] - 182s 18s/step - loss: 2.6199 - accuracy: 0.0726 - val_loss: 2.5384 - val_accuracy: 0.1641
# Epoch 6/10
# 10/10 [==============================] - 191s 19s/step - loss: 2.5295 - accuracy: 0.1120 - val_loss: 2.4384 - val_accuracy: 0.1328
# Epoch 7/10
# 10/10 [==============================] - 193s 19s/step - loss: 2.4771 - accuracy: 0.1410 - val_loss: 2.4687 - val_accuracy: 0.1484
# Epoch 8/10
# 10/10 [==============================] - 194s 19s/step - loss: 2.5428 - accuracy: 0.1021 - val_loss: 2.5202 - val_accuracy: 0.1484
# Epoch 9/10
#  9/10 [==========================>...] - ETA: 17s - loss: 2.4197 - accuracy: 0.2120

# %%
# define the early stopping
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                              patience=5)

# perfrom search for best parameters
tuner.search(train_generators, 
             validation_data=valid_generators, 
             epochs=30, 
             callbacks=[stop_early],
             validation_steps=4,
             steps_per_epoch=10)

# get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
# Out:
# Trial 180 Complete [01h 08m 25s]
# val_accuracy: 0.34375
#
# Best val_accuracy So Far: 0.40625
# Total elapsed time: 09h 56m 27s
# INFO:tensorflow:Oracle triggered exit

# %%
print('Units: ',best_hps.get('units'), ', Learning rate: ', best_hps.get('learning_rate'), ', Convolutional blocks: ', best_hps.get('conv_blocks'), ', Dropout rate: ', best_hps.get('dropout'))
# Out:
# Units:  96 , Learning rate:  0.0001 , Convolutional blocks:  2 , Dropout rate:  0.0

# %%
# build model based on the hparams

def architecture_model(input_shape,
                conv_layers,
                conv_activation,
                conv_dropout,
                units,
                output_activation,
                optimizer,
                loss,
                metrics,
                verbose=1):
    
    np.random.seed(1234) # Define the seed for numpy to have reproducible experiments.
    set_seed(9876) # Define the seed for Tensorflow to have reproducible experiments.
    
    # Define the input layer.
    input = Input(
        shape=input_shape,
        name='Input'
    )

    x = input
    # Define the convolutional layers.
    for i in range(conv_layers):
        x = Conv2D(
            filters=8*(2**(i+1)),
            kernel_size=(3, 3),
            strides=(1, 1),
            padding='same',
            dilation_rate=(1, 1),
            activation=conv_activation,
            name='Conv2D-{0:d}'.format(i + 1)
        )(x)
        x = MaxPool2D(
            pool_size=(2, 2),
            strides=(2, 2),
            padding='same',
            name='MaxPool2D-{0:d}'.format(i + 1)
        )(x)
        if conv_dropout:
            x = Dropout(
                rate=0.2,
                name='Dropout-{0:d}'.format(i + 1)
            )(x)
    # Flatten the convolved images so as to input them to a Dense Layer
    x = Flatten(name='Flatten')(x)
    
    # Define the output layer.
    output = Dense(
        units=units,
        activation=output_activation,
        name='Output'
    )(x)

    # Define the model and train it.
    model = Model(inputs=input, 
                  outputs=output)
    model.compile(optimizer=optimizer, 
                  loss=loss, 
                  metrics=metrics)
    
    # print summary and architecture
    model.summary()

    return model

# %% [markdown]
# # Best model

# %% [markdown]
# ## Build

# %%
# Units:  96 , 
#     Learning rate:  0.0001 , 
#         Convolutional blocks:  2 , 
#             Dropout rate:  0.0

# %%
model = architecture_model(input_shape = (320,320,3),
                        conv_layers = 2,
                        conv_activation = 'relu',
                        conv_dropout = 0,
                        units = 14,
                        output_activation = 'softmax',
                        optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001),
                        loss = 'sparse_categorical_crossentropy',
                        metrics = ['accuracy'])
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 320, 320, 3)]     0
# _________________________________________________________________
# Conv2D-1 (Conv2D)            (None, 320, 320, 16)      448
# _________________________________________________________________
# MaxPool2D-1 (MaxPooling2D)   (None, 160, 160, 16)      0
# _________________________________________________________________
# Conv2D-2 (Conv2D)            (None, 160, 160, 32)      4640
# _________________________________________________________________
# MaxPool2D-2 (MaxPooling2D)   (None, 80, 80, 32)        0
# _________________________________________________________________
# Flatten (Flatten)            (None, 204800)            0
# _________________________________________________________________
# Output (Dense)               (None, 14)                2867214
# =================================================================
# Total params: 2,872,302
# Trainable params: 2,872,302
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', 
                                             patience=8,
                                             restore_best_weights=True)
    
validation_steps = math.ceil(valid_generators.n/ (4*valid_generators.batch_size))
print("Using validation_steps = %d" % validation_steps)
steps_per_epoch = math.ceil(train_generators.n / (8*train_generators.batch_size))
print("Using steps_per_epoch = %d" % steps_per_epoch)

history = model.fit(train_generators,
                    validation_data = valid_generators,
                    validation_steps = validation_steps,
                    steps_per_epoch = steps_per_epoch,
                    epochs=80,
                    verbose=1,
                    callbacks=[callbacks]
)
# Out:
# Using validation_steps = 30
# Using steps_per_epoch = 130
# /usr/local/lib/python3.8/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.8/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/80
# 130/130 [==============================] - 112s 853ms/step - loss: 2.4583 - accuracy: 0.1686 - val_loss: 2.2213 - val_accuracy: 0.2792
# Epoch 2/80
# 130/130 [==============================] - 102s 782ms/step - loss: 2.2170 - accuracy: 0.2722 - val_loss: 2.1336 - val_accuracy: 0.2677
# Epoch 3/80
# 130/130 [==============================] - 107s 820ms/step - loss: 2.0809 - accuracy: 0.3162 - val_loss: 2.1307 - val_accuracy: 0.2979
# Epoch 4/80
# 130/130 [==============================] - 101s 770ms/step - loss: 2.0463 - accuracy: 0.3261 - val_loss: 2.0061 - val_accuracy: 0.3208
# Epoch 5/80
# 130/130 [==============================] - 109s 831ms/step - loss: 1.9969 - accuracy: 0.3361 - val_loss: 2.0123 - val_accuracy: 0.3187
# Epoch 6/80
# 130/130 [==============================] - 112s 859ms/step - loss: 1.9354 - accuracy: 0.3431 - val_loss: 1.9524 - val_accuracy: 0.3240
# Epoch 7/80
# 130/130 [==============================] - 108s 822ms/step - loss: 1.8995 - accuracy: 0.3646 - val_loss: 1.9408 - val_accuracy: 0.3448
# Epoch 8/80
# 130/130 [==============================] - 106s 814ms/step - loss: 1.8810 - accuracy: 0.3628 - val_loss: 1.8756 - val_accuracy: 0.3427
# Epoch 9/80
# 130/130 [==============================] - 110s 844ms/step - loss: 1.9043 - accuracy: 0.3536 - val_loss: 1.7771 - val_accuracy: 0.3875
# Epoch 10/80
# 130/130 [==============================] - 102s 783ms/step - loss: 1.8442 - accuracy: 0.3798 - val_loss: 1.7727 - val_accuracy: 0.3823
# Epoch 11/80
# 130/130 [==============================] - 106s 810ms/step - loss: 1.8428 - accuracy: 0.3887 - val_loss: 1.8347 - val_accuracy: 0.3865
# Epoch 12/80
# 130/130 [==============================] - 101s 772ms/step - loss: 1.7774 - accuracy: 0.3763 - val_loss: 1.7629 - val_accuracy: 0.3854
# Epoch 13/80
# 130/130 [==============================] - 109s 837ms/step - loss: 1.7769 - accuracy: 0.3915 - val_loss: 1.8177 - val_accuracy: 0.3719
# Epoch 14/80
# 130/130 [==============================] - 108s 826ms/step - loss: 1.7929 - accuracy: 0.3903 - val_loss: 1.7811 - val_accuracy: 0.3719
# Epoch 15/80
# 130/130 [==============================] - 108s 828ms/step - loss: 1.7541 - accuracy: 0.3977 - val_loss: 1.7376 - val_accuracy: 0.4083
# Epoch 16/80
# 130/130 [==============================] - 108s 827ms/step - loss: 1.7256 - accuracy: 0.4200 - val_loss: 1.6937 - val_accuracy: 0.4333
# Epoch 17/80
# 130/130 [==============================] - 100s 767ms/step - loss: 1.7056 - accuracy: 0.4156 - val_loss: 1.7464 - val_accuracy: 0.3969
# Epoch 18/80
# 130/130 [==============================] - 100s 768ms/step - loss: 1.7253 - accuracy: 0.4140 - val_loss: 1.7093 - val_accuracy: 0.4010
# Epoch 19/80
# 130/130 [==============================] - 100s 765ms/step - loss: 1.7197 - accuracy: 0.4021 - val_loss: 1.6847 - val_accuracy: 0.4073
# Epoch 20/80
# 130/130 [==============================] - 99s 760ms/step - loss: 1.6977 - accuracy: 0.4126 - val_loss: 1.6711 - val_accuracy: 0.4281
# Epoch 21/80
# 130/130 [==============================] - 99s 761ms/step - loss: 1.7165 - accuracy: 0.4114 - val_loss: 1.6309 - val_accuracy: 0.4531
# Epoch 22/80
# 130/130 [==============================] - 99s 756ms/step - loss: 1.6449 - accuracy: 0.4306 - val_loss: 1.6352 - val_accuracy: 0.4271
# Epoch 23/80
# 130/130 [==============================] - 99s 757ms/step - loss: 1.6488 - accuracy: 0.4175 - val_loss: 1.6444 - val_accuracy: 0.4427
# Epoch 24/80
# 130/130 [==============================] - 99s 759ms/step - loss: 1.6263 - accuracy: 0.4358 - val_loss: 1.6071 - val_accuracy: 0.4344
# Epoch 25/80
# 130/130 [==============================] - 100s 764ms/step - loss: 1.5946 - accuracy: 0.4394 - val_loss: 1.6602 - val_accuracy: 0.4385
# Epoch 26/80
# 130/130 [==============================] - 99s 760ms/step - loss: 1.6108 - accuracy: 0.4421 - val_loss: 1.5685 - val_accuracy: 0.4583
# Epoch 27/80
# 130/130 [==============================] - 100s 763ms/step - loss: 1.6229 - accuracy: 0.4377 - val_loss: 1.6152 - val_accuracy: 0.4458
# Epoch 28/80
# 130/130 [==============================] - 99s 761ms/step - loss: 1.6314 - accuracy: 0.4356 - val_loss: 1.6207 - val_accuracy: 0.4354
# Epoch 29/80
# 130/130 [==============================] - 100s 763ms/step - loss: 1.6276 - accuracy: 0.4428 - val_loss: 1.5657 - val_accuracy: 0.4510
# Epoch 30/80
# 130/130 [==============================] - 100s 766ms/step - loss: 1.5719 - accuracy: 0.4541 - val_loss: 1.5609 - val_accuracy: 0.4625
# Epoch 31/80
# 130/130 [==============================] - 100s 765ms/step - loss: 1.5779 - accuracy: 0.4492 - val_loss: 1.5380 - val_accuracy: 0.4583
# Epoch 32/80
# 130/130 [==============================] - 100s 764ms/step - loss: 1.6232 - accuracy: 0.4480 - val_loss: 1.5313 - val_accuracy: 0.4500
# Epoch 33/80
# 130/130 [==============================] - 100s 765ms/step - loss: 1.5864 - accuracy: 0.4447 - val_loss: 1.5890 - val_accuracy: 0.4198
# Epoch 34/80
# 130/130 [==============================] - 100s 765ms/step - loss: 1.5705 - accuracy: 0.4532 - val_loss: 1.5664 - val_accuracy: 0.4583
# Epoch 35/80
# 130/130 [==============================] - 99s 760ms/step - loss: 1.5542 - accuracy: 0.4689 - val_loss: 1.5193 - val_accuracy: 0.4510
# Epoch 36/80
# 130/130 [==============================] - 100s 761ms/step - loss: 1.5215 - accuracy: 0.4662 - val_loss: 1.5410 - val_accuracy: 0.4542
# Epoch 37/80
# 130/130 [==============================] - 99s 757ms/step - loss: 1.5527 - accuracy: 0.4591 - val_loss: 1.5186 - val_accuracy: 0.4563
# Epoch 38/80
# 130/130 [==============================] - 99s 754ms/step - loss: 1.5402 - accuracy: 0.4619 - val_loss: 1.5609 - val_accuracy: 0.4510

# %%
# save model

model.save("data/models/finetuned_deep_augment_14classes_80epochs.h5")
import json
with open("data/history/history_finetuned_deep_augment_14classes_80epochs.json", "w") as file:
    json.dump(history.history, file)

# %% [markdown]
# ## Plots

# %%
import lib.plot_learning_curves as plot_learning_curves

# %%
plot_learning_curves.plot_history_all(history,
                 'based_model_finetuned',
                80,
                'deep_augment')

# %% [markdown]
# ## Evaluate

# %%
# evaluate the model
eval_result1 = model.evaluate(test_generators)
print("[test loss, test accuracy]:", eval_result1)
eval_result2 = model.evaluate(train_generators)
print("[train loss, train accuracy]:", eval_result2)
eval_result3 = model.evaluate(valid_generators)
print("[valid loss, valid accuracy]:", eval_result3)
# Out:
# 100/100 [==============================] - 17s 167ms/step - loss: 1.8592 - accuracy: 0.3616
# [test loss, test accuracy]: [1.859245777130127, 0.3615889847278595]
# 1034/1034 [==============================] - 648s 627ms/step - loss: 1.6037 - accuracy: 0.4427
# [train loss, train accuracy]: [1.6036646366119385, 0.4427146315574646]
# 117/117 [==============================] - 19s 166ms/step - loss: 1.6014 - accuracy: 0.4348
# [valid loss, valid accuracy]: [1.601372241973877, 0.4348175823688507]

# %%
def eval_func_multi(y_true, y_prob):
    """
    A function calculating the different evaluation metrics on the test set.
    Converts prediction probabilities y_prob to predicted labels y_pred
    """
    y_pred = np.array(y_prob)
    y_true = np.array(y_true)

    print(f"Test accuracy: {round(accuracy_score(y_true, y_pred)*100, 2)} %")
    print(f"Test F1 score: {round(f1_score(y_true, y_pred)*100, 2)} %")
    print(f"Test Precision score: {round(precision_score(y_true, y_pred)*100, 2)} %")
    print(f"Test Recall score: {round(recall_score(y_true, y_pred)*100, 2)} %")

# %%
# eval_func_multi(test['new_class'], 
#           model.predict(test_generators))

# %% [markdown]
# ## Prediction

# %%
# # obtaining predictions for mode
# from sklearn.metrics import classification_report

# # test set
# predictions_test = model.predict(test_generators)

# def round_predictions(predictions):
#   return [round(item) for item in predictions]

# predictions_test = [round_predictions(item) for item in predictions_test]

# predictions_test=np.array(predictions_test)

# report_test  = classification_report(test['new_class'], 
#                                      predictions_test, 
#                                      output_dict=True)

# import pprint
# pp = pprint.PrettyPrinter(indent=2)
# pp.pprint(report_test)

# %%
# # make dataframe

# import pandas as pd

# report_test_df = pd.DataFrame(report_test)
# round(report_test_df*100, 2)

# %%
# # export for latex

# print(round(report_test_df*100, 2).to_latex(index=False))
