# %% [markdown]
# Notes:
#
# * Metrics exported
# * Done! calculating train, valid accuracy

# %%
import tensorflow as tf
import lib.data_loader as data_loader
import lib.plot_learning_curves as plot_learning_curves
import models.base_model as base_model
import models.densenet as densenet
import models.resnet as resnet
import models.inception_v3 as inception
import models.xception as xception
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import math
import matplotlib.image as mpimg
# from tqdm import tqdm
from PIL import Image
import tensorflow as tf
from tensorflow import keras
import random, os
import numpy as np
import pandas as pd
import json

# import cv2
import matplotlib.pyplot as plt
from matplotlib.pyplot import *

# %matplotlib inline
from mpl_toolkits.axes_grid1 import make_axes_locatable
from glob import glob
import gc
# from skimage.transform import resize
from tensorflow.keras import backend as K # Importing Keras backend (by default it is Tensorflow)
from tensorflow.keras.layers import Input, Conv2D, Dense, Dropout, Flatten, MaxPool2D # Layers to be used for building our model
from tensorflow.keras.models import Model # The class used to create a model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.random import set_seed

from sklearn.metrics import f1_score, recall_score, precision_score

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
! pip install -q -U keras-tuner
import keras_tuner as kt

from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.4.0
# Train model
# Tensorflow version 2.4.0
# Tensorflow version 2.4.0
# Tensorflow version 2.4.0
# Tensorflow version 2.4.0
# WARNING: You are using pip version 20.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Tensorflow version 2.4.0

# %%
import models.xception as xception

# %%
# mount data
data_path = 'data/MURA-v1.1/'
directory = 'data/'
! pwd
train_generators, valid_generators, test_generators, test=data_loader.load_all("deep_augment")
# Out:
# /tf
#
# Import train and test data
#
# Doing a light data augmentation
#
# Create training, validation and test set
#
# Found 33197 validated image filenames.
# Found 3611 validated image filenames.
# Found 3197 validated image filenames.
# Data munging completed

# %% [markdown]
# # Xception

# %%
def clean_up(model):
    K.clear_session()
    del model
    gc.collect()

# %%
bodypart = '14classes'
# for bodypart in bodyparts:
print(bodypart)
print("\nBuild model\n")
model =  xception.build_model_on_xception_14classes()
print('\nTrain model\n')
print(bodypart)
xception_model_top_histories = xception.train_model_14classes(model, 
                                                 valid_generators,
                                                 train_generators,
                                                 50)
print('\nSave training history\n')
with open("data/history/history_xception_14classes_top_50epochs_deep_augment_fixed_softmax.json", "w") as file:
    json.dump(xception_model_top_histories.history, file)
    print('\nSave model\n')
model.save("data/models/xception_14classes_top_50epochs_deep_augment_fixed_softmax")
model.save("data/models/xception_14classes_top_50epochs_deep_augment_fixed_softmax.h5")
# Out:
# 14classes
#
# Build model
#
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 320, 320, 3)]     0
# _________________________________________________________________
# xception (Functional)        (None, 10, 10, 2048)      20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 14)                28686
# =================================================================
# Total params: 20,890,166
# Trainable params: 28,686
# Non-trainable params: 20,861,480
# _________________________________________________________________
#
# Train model
#
# 14classes
# Using validation_steps = 29
# Using steps_per_epoch = 130
# /usr/local/lib/python3.8/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.8/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/50
# 130/130 [==============================] - 687s 5s/step - loss: 2.1315 - accuracy: 0.2988 - val_loss: 1.4778 - val_accuracy: 0.5043
# Epoch 2/50
# 130/130 [==============================] - 726s 6s/step - loss: 1.4350 - accuracy: 0.5266 - val_loss: 1.3034 - val_accuracy: 0.5205
# Epoch 3/50
# 130/130 [==============================] - 610s 5s/step - loss: 1.2877 - accuracy: 0.5507 - val_loss: 1.1357 - val_accuracy: 0.5862
# Epoch 4/50
# 130/130 [==============================] - 613s 5s/step - loss: 1.1863 - accuracy: 0.5942 - val_loss: 1.1095 - val_accuracy: 0.6056
# Epoch 5/50
# 130/130 [==============================] - 672s 5s/step - loss: 1.1501 - accuracy: 0.5805 - val_loss: 1.1007 - val_accuracy: 0.5905
# Epoch 6/50
# 130/130 [==============================] - 640s 5s/step - loss: 1.0823 - accuracy: 0.6002 - val_loss: 1.0607 - val_accuracy: 0.6121
# Epoch 7/50
# 130/130 [==============================] - 661s 5s/step - loss: 1.1011 - accuracy: 0.5901 - val_loss: 1.0381 - val_accuracy: 0.5948
# Epoch 8/50
# 130/130 [==============================] - 762s 6s/step - loss: 1.0386 - accuracy: 0.6180 - val_loss: 1.0248 - val_accuracy: 0.6175
# Epoch 9/50
# 130/130 [==============================] - 983s 8s/step - loss: 1.0184 - accuracy: 0.6162 - val_loss: 1.0216 - val_accuracy: 0.6034
# Epoch 10/50
# 130/130 [==============================] - 822s 6s/step - loss: 1.0268 - accuracy: 0.6111 - val_loss: 0.9775 - val_accuracy: 0.6207
# Epoch 11/50
# 130/130 [==============================] - 768s 6s/step - loss: 0.9810 - accuracy: 0.6300 - val_loss: 0.9359 - val_accuracy: 0.6584
# Epoch 12/50
# 130/130 [==============================] - 787s 6s/step - loss: 0.9815 - accuracy: 0.6353 - val_loss: 0.9827 - val_accuracy: 0.6444
# Epoch 13/50
# 130/130 [==============================] - 753s 6s/step - loss: 0.9593 - accuracy: 0.6341 - val_loss: 0.9607 - val_accuracy: 0.6476
# Epoch 14/50
# 130/130 [==============================] - 771s 6s/step - loss: 0.9601 - accuracy: 0.6379 - val_loss: 0.9535 - val_accuracy: 0.6541
# Epoch 15/50
# 130/130 [==============================] - 742s 6s/step - loss: 0.9268 - accuracy: 0.6416 - val_loss: 0.9138 - val_accuracy: 0.6659
# Epoch 16/50
# 130/130 [==============================] - 777s 6s/step - loss: 0.9486 - accuracy: 0.6281 - val_loss: 0.9242 - val_accuracy: 0.6487
# Epoch 17/50
# 130/130 [==============================] - 755s 6s/step - loss: 0.9552 - accuracy: 0.6502 - val_loss: 0.9847 - val_accuracy: 0.6336
# Epoch 18/50
# 130/130 [==============================] - 739s 6s/step - loss: 0.9367 - accuracy: 0.6421 - val_loss: 0.9105 - val_accuracy: 0.6692
# Epoch 19/50
# 130/130 [==============================] - 772s 6s/step - loss: 0.9324 - accuracy: 0.6498 - val_loss: 0.9546 - val_accuracy: 0.6336
# Epoch 20/50
# 130/130 [==============================] - 757s 6s/step - loss: 0.9020 - accuracy: 0.6557 - val_loss: 0.9298 - val_accuracy: 0.6422
# Epoch 21/50
# 130/130 [==============================] - 671s 5s/step - loss: 0.8767 - accuracy: 0.6641 - val_loss: 0.9346 - val_accuracy: 0.6401
# Epoch 22/50
# 130/130 [==============================] - 701s 5s/step - loss: 0.8829 - accuracy: 0.6570 - val_loss: 0.9210 - val_accuracy: 0.6681
# Epoch 23/50
# 130/130 [==============================] - 726s 6s/step - loss: 0.8755 - accuracy: 0.6605 - val_loss: 0.9166 - val_accuracy: 0.6444
# Epoch 24/50
# 130/130 [==============================] - 734s 6s/step - loss: 0.9030 - accuracy: 0.6510 - val_loss: 0.9169 - val_accuracy: 0.6476
# Epoch 25/50
# 130/130 [==============================] - 737s 6s/step - loss: 0.9062 - accuracy: 0.6551 - val_loss: 0.9098 - val_accuracy: 0.6541
# Epoch 26/50
# 130/130 [==============================] - 684s 5s/step - loss: 0.8740 - accuracy: 0.6477 - val_loss: 0.8867 - val_accuracy: 0.6756
# Epoch 27/50
# 130/130 [==============================] - 697s 5s/step - loss: 0.8985 - accuracy: 0.6569 - val_loss: 0.9211 - val_accuracy: 0.6358
# Epoch 28/50
# 130/130 [==============================] - 633s 5s/step - loss: 0.8764 - accuracy: 0.6763 - val_loss: 0.9419 - val_accuracy: 0.6498
# Epoch 29/50
# 130/130 [==============================] - 666s 5s/step - loss: 0.8877 - accuracy: 0.6513 - val_loss: 0.8805 - val_accuracy: 0.6703
# Epoch 30/50
# 130/130 [==============================] - 632s 5s/step - loss: 0.8827 - accuracy: 0.6500 - val_loss: 0.8776 - val_accuracy: 0.6584
# Epoch 31/50
# 130/130 [==============================] - 607s 5s/step - loss: 0.8605 - accuracy: 0.6517 - val_loss: 0.8986 - val_accuracy: 0.6433
# Epoch 32/50
#  94/130 [====================>.........] - ETA: 2:21 - loss: 0.8464 - accuracy: 0.6815
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
model.evaluate(test_generators, verbose=1)
# Out:
# 100/100 [==============================] - 394s 4s/step - loss: 1.0152 - accuracy: 0.6206
# [1.015210509300232, 0.6205818057060242]

# %%
model.evaluate(train_generators, verbose=1)
# Out:
# /usr/local/lib/python3.8/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.8/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# 1038/1038 [==============================] - 3958s 4s/step - loss: 0.8146 - accuracy: 0.6867
# [0.8146106600761414, 0.6866885423660278]

# %%
model.evaluate(valid_generators, verbose=1)
# Out:
# 113/113 [==============================] - 450s 4s/step - loss: 0.8616 - accuracy: 0.6741
# [0.8615542054176331, 0.6740515232086182]

# %%
plot_learning_curves.plot_history_all(xception_model_top_histories, 
                                 'xception_14classes_model_top_fixed_softmax',
                                 50,
                                 data_augmentation='deep_augment')
